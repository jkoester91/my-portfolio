# %% [markdown]
# <div style="border: 5px solid purple; padding: 15px; margin: 5px">
# <b> Reviewer's comment</b>
#
# Hi Jimmy, my name is Svetlana (https://hub.tripleten.com/u/6dee602c). Congratulations on submitting the first integrated project! 🎉
#
#
# Before we start, I want to pay your attention to the color marking:
#
#
#
#
# <div style="border: 5px solid green; padding: 15px; margin: 5px">
#
# Great solutions and ideas that can and should be used in the future are in green comments. Some of them are:
#
#
# - You have successfully explored the dataframe. This is an important step, since it helps us identify the issues a dataframe may have and how the distributions look like;
#
#
# - Followed the logical sequence defined in the project description, well done!
#
#
# - You have chosen time interval for further analysis;
#
#
# - Displayed a lot of charts, which is also important, since the results must be easy to interpret;
#
#
# - Formulated a conclusion about regional preferences, platform dominance, and genre trends. We always need to analyze the results, since it may reveal interesting and important insights;
#
#
# - Conducted statistical tests;
#
#
# - Wrote an excellent conclusion! A well-written conclusion shows how the project met its objectives and provides a concise and understandable summary for those who may not have been involved in the details of the project. Good job!
#
# </div>
#
# <div style="border: 5px solid gold; padding: 15px; margin: 5px">
# <b> Reviewer's comment </b>
#
# Yellow color indicates what should be optimized. This is not necessary, but it will be great if you make changes to this project. I've left several recommendations throughout the project. Please take a look.
#
# </div>
# <div style="border: 5px solid red; padding: 15px; margin: 5px">
# <b> Reviewer's comment </b>
#
# Issues that must be corrected to achieve accurate results are indicated in red comments. Please note that the project cannot be accepted until these issues are resolved. More specifically:
#
#
#
# - The time interval should be updated as mentioned in one of my comments.
#
#
#
# - Please use relevant time interval in each task after you choose it.
#
#
#
# - Finally, please add hypotheses wordings and explain why you choose a specific statistical test and pvalue.
#
#
#
#
#
# There may be some other small issues that you may find in my comments.
# </div>
# <hr>
#
# <font color='dodgerblue'>**To sum up:**</font> you did a great job here, thank you so much! Actually the project is almost perfect, and the updates should not take much time. If you have any questions, please feel free to ask. I will wait the project for the second review 😊
#
#
# <hr>
#
# Please use some color other than those listed to highlight answers to my comments.
# I would also ask you **not to change, move or delete my comments** to make it easier for me to navigate during the next review.
#
#
#
# <hr>
#
#
# ✍️ Please check out these two articles about pvalue: [Statisticians issue warning over misuse of P values](https://www.nature.com/articles/nature.2016.19503) and [Misuse of p-values](https://en.wikipedia.org/wiki/Misuse_of_p-values). They are quite important because sometimes pvalue is interpreted incorrectly.
#
#
# [This article](https://www.scribbr.com/statistics/statistical-tests/) gives a cursory understanding of which test to choose. You may find it useful.
#
# <hr>
#
# 📌 Please feel free to schedule a 1:1 sessions with our tutors or TAs, book 1-1 session [here](https://calendly.com/tripleten-ds-experts-team), join daily coworking sessions, or ask questions on TripleTen Hub if you need assistance 😉
# <div style="border: 5px solid blue; padding: 10px; margin: 5px">
# Hi Svetlana! Thanks for taking the time to review my project and for your guidance in helping me make the necessary improvements! You'll find my updated comments highlighted in a blue outlined box for clarity.
# </div>
# </div>

# %% [markdown]
# <div style="border: 5px solid purple; padding: 15px; margin: 5px">
# <b> Reviewer's comment 2</b>
#
# > Hi Svetlana! Thanks for taking the time to review my project and for your guidance in helping me make the necessary improvements! You'll find my updated comments highlighted in a blue outlined box for clarity.
#
#
# Understood! :)
#
#
# Thank you very much for such a good job!
#
#
# Here you learned how to prepare raw data for further analysis, how to visualize and interpret data using line charts, box plots, and scatter plots to uncover patterns and correlations, how to build user profiles, formulate and test statistical hypotheses, and draw actionable business conclusions to inform marketing strategies and future planning. Excellent job here! I hope you liked this project.
#
#
# I've left a couple of new comments with digit 2. However, there are no issues that need to be fixed, so I can accept the project. Congratulations and good luck! 😊
#
#
# </div>

# %% [markdown]
# # Video Game Sales Analysis Project
# ## Project Overview
#
# In this project, you'll analyze video game sales data to identify patterns that determine a game's success. Working as an analyst for the online store Ice, you'll use this information to help plan future advertising campaigns.
#
# ## Environment Setup and Required Libraries

# %%
# Import all required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st
import seaborn as sns

# %% [markdown]
# ## Step 1: Loading and Initial Data Exploration
#
# First, let's load our dataset and examine its basic properties:

# %%
# Load the dataset
games = pd.read_csv('/datasets/games.csv')

# %%
# Display basic information about the dataset
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# ##### Looks like we're missing a lot of data. I'm wondering why we're missing 2 lines for Name, and Genre.

# %%
# Check for duplicate entries
display(games.duplicated().sum())
# Out:
# 0

# %%
# display a sample header to see what the df looks like
display(games.sample(10))
# Out:
#                                                Name Platform  Year_of_Release  \
# 12878                                   Chocolatier       DS           2010.0
# 7461                          NCAA March Madness 07     X360           2007.0
# 2768                    The Elder Scrolls V: Skyrim     XOne           2016.0
# 9088   Shonen Jump's Shaman King: Master of Spirits      GBA           2004.0
# 8329                      Major League Baseball 2K9      PS2           2009.0
# 15327                                 G1 Jockey Wii      Wii           2007.0
# 7444                             Hitman: HD Trilogy      PS3           2013.0
# 12907                                       BlowOut       XB           2003.0
# 12640                              Dance Sensation!      Wii           2010.0
# 15381                          Meitantei Evangelion      PS2           2007.0
#
#               Genre  NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score  \
# ...

# %% [markdown]
# ### Key Questions to Answer:
# - What's the total number of records in our dataset?
#     - There are 16715 records in our dataset
# - What data types are present in each column?
#     - We have 5 columns that are object then we have 6 columns that are float 64 including the year_of_release columns.
# - Are there any obvious issues with the data?
#     - We are missing a lot of data for Critic_score, User_score, Year_of_release, and Rating
# - Do we see any immediate patterns or anomalies?
#     - The Year_of_Release shouldn't have a decimal point (float 64), we will need to change it to an INT

# %% [markdown]
# <div style="border: 5px solid green; padding: 10px; margin: 5px">
# <b>   Reviewer's comment  </b>
#
# Good! </div>

# %% [markdown]
# ## Step 2: Data Preparation
#
# ### 2.1 Standardizing Column Names

# %%
# Convert column names to lowercase
games.columns = games.columns.str.lower()

# %%
# Verify the changes
display(games.head())
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# ### 2.2 Data Type Conversion

# %%
# Check current data types
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
# Make changes to data types if necessary
# Change year_of_release from float64 to int64
games['year_of_release'] = games['year_of_release'].fillna(0).astype('int')

# Describe the columns where the data types have been changed and why.
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16715 non-null  int64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# #### The reason why I'm replacing NaNs for year_of_release to 0 is so I can convert the column to Int64. Since we're not likely to calculate the average of the year, we're marking NaNs as 0 meaning 'Unknown'

# %% [markdown]
# #### we can replace two missing values for name as "unk" (unknown)

# %%
# filling in the blank in name to 'unk'
games['name'] = games['name'].fillna('unk')

#verifying that blank name has been changed to 'unk'
display(games[games['name'] == 'unk'])
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    unk      GEN             1993   NaN      1.78      0.53      0.00
# 14244  unk      GEN             1993   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %%
# Pay attention to the abbreviation TBD (to be determined). Specify how you intend to handle such cases.
print(games['user_score'].value_counts(dropna=False))
# Out:
# NaN    6701
# tbd    2424
# 7.8     324
# 8       290
# 8.2     282
#        ...
# 2.3       2
# 0.9       2
# 1.9       2
# 9.7       1
# 0         1
# Name: user_score, Length: 97, dtype: int64

# %% [markdown]
# #### We see that there's over 2400 of tbds. Now let's see if they're very recent or have random year_of_release dates

# %%
# print only the df that has tbd in uder_score rating
tbd = games[games['user_score'] == 'tbd']
display(tbd.head())
# Out:
#                                          name platform  year_of_release  \
# 119                             Zumba Fitness      Wii             2010
# 301            Namco Museum: 50th Anniversary      PS2             2005
# 520                           Zumba Fitness 2      Wii             2011
# 645                              uDraw Studio      Wii             2010
# 657  Frogger's Adventures: Temple of the Frog      GBA                0
#
#          genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 119     Sports      3.45      2.59       0.0         0.66           NaN
# 301       Misc      2.08      1.35       0.0         0.54          61.0
# 520     Sports      1.51      1.03       0.0         0.27           NaN
# 645       Misc      1.65      0.57       0.0         0.20          71.0
# 657  Adventure      2.15      0.18       0.0         0.07          73.0
#
#     user_score rating
# 119        tbd      E
# 301        tbd   E10+
# 520        tbd      T
# ...

# %% [markdown]
# #### Okay this is interesting. Why are there TBD user_score in 2005, 2010, etc. when the game has been out for that long?

# %% [markdown]
# ### 2.3 Handling Missing Values

# %%
# Examine missing values
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16715 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16715 non-null  int64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 1.4+ MB

# %%
# Calculate percentage of missing values
# Let's start with missing data for critic_score
missing_critic = games['critic_score'].isna().sum()

# calculate the missing value % for critic_score
missing_critic_avg = (missing_critic / 16175) * 100

print(f"the percentage of missing value for critic_socre is {missing_critic_avg:.2f}%")

# next, user_score (we will count tbds as values for now)
missing_user = games['user_score'].isna().sum()

# calculate the missing value % for user_score
missing_user_avg = (missing_user / 16175) * 100

print(f"the percentage of missing value for user_score is {missing_user_avg:.2f}%")

# lastly, ratings
missing_rating = games['rating'].isna().sum()

# calculate the missing value % for missing_rating
missing_rating_avg = (missing_rating / 16175) * 100

print(f"the percentage of missing value for rating is {missing_rating_avg:.2f}%")

# Calculate the tbds % in user_score
tbd_sum = (games['user_score'] == 'tbd').sum()
tbd_avg = (tbd_sum / 16175) * 100

print(f"the percentage of tbds in user_score is {tbd_avg:.2f}%")
# Out:
# the percentage of missing value for critic_socre is 53.03%
# the percentage of missing value for user_score is 41.43%
# the percentage of missing value for rating is 41.83%
# the percentage of tbds in user_score is 14.99%

# %% [markdown]
# ### having this many missing values could ruin our hypothesis testing. We need to decide what we should do with the missing values! From the looks of it, we should just leave it blank because if we put 0 to fill in the NaNs, it would destroy the rating's average!

# %% [markdown]
# #### Since we know the missing values for each columns for the scores and rating, we should calculate how many rows has all NaNs

# %%
# Analyze patterns in missing values
# Let's calculate how many rows of NaNs for each columns
print("Missing values (NaN):")
print(f"critic_score: {missing_critic}")
print(f"user_score: {missing_user}")
print(f"rating: {missing_rating}")
print(f"'tbd' values in user_score: {tbd_sum}")
# Out:
# Missing values (NaN):
# critic_score: 8578
# user_score: 6701
# rating: 6766
# 'tbd' values in user_score: 2424

# %% [markdown]
# ##### Let's try to see a pattern (the most year_of_release, Genre, and sales) when we filter to each NaNs for each column (critic_score, user_score, rating). But first, let's see if all the missing values has to do with the data being old

# %%
# looking to see if there's a pattern for the year_of_release for the NaNs in critic_score
nan_critic_score = games[games['critic_score'].isna()]
print(nan_critic_score['year_of_release'].value_counts(ascending=False))
# Out:
# 2009    775
# 2010    755
# 2008    712
# 2011    636
# 2007    505
# 2006    386
# 2015    381
# 1998    351
# 2012    332
# 2014    320
# 1999    299
# 2005    284
# 1997    272
# 2013    271
# 2016    270
# 1996    255
# 1995    219
# 2000    207
# 2002    202
# 2004    201
# 2003    190
# 2001    156
# 1994    120
# 0       115
# 1993     62
# 1981     46
# 1992     42
# 1991     41
# 1982     36
# 1986     21
# 1989     17
# 1983     17
# 1990     16
# 1987     16
# 1984     14
# 1988     14
# 1985     13
# 1980      9
# Name: year_of_release, dtype: int64

# %%
# let's try with platform
print(nan_critic_score['platform'].value_counts(ascending=False))
# Out:
# DS      1434
# PS       997
# PS2      863
# PSP      747
# Wii      735
# PS3      511
# GBA      384
# 3DS      352
# X360     346
# N64      319
# PSV      310
# PC       259
# SNES     239
# SAT      173
# PS4      140
# 2600     133
# GC       108
# XB        99
# NES       98
# GB        98
# XOne      78
# WiiU      57
# DC        38
# GEN       29
# NG        12
# WS         6
# SCD        6
# 3DO        3
# TG16       2
# PCFX       1
# GG         1
# Name: platform, dtype: int64

# %% [markdown]
# ##### Ok wow, we are missing a lot of critic_score from the most popular platforms!

# %%
# finally, with genre
print(nan_critic_score['genre'].value_counts(ascending=False))
# Out:
# Action          1479
# Misc            1227
# Sports          1154
# Adventure        980
# Role-Playing     761
# Simulation       521
# Racing           507
# Fighting         440
# Platform         391
# Strategy         381
# Shooter          379
# Puzzle           356
# Name: genre, dtype: int64

# %%
# Count combinations of all three columns
result = nan_critic_score.groupby(['year_of_release', 'platform', 'genre']).size()
print(result.sort_values(ascending=False))
# Out:
# year_of_release  platform  genre
# 2008             DS        Misc            74
# 2009             DS        Simulation      66
# 2010             DS        Misc            66
# 2008             DS        Simulation      65
# 2010             PSP       Adventure       63
#                                            ..
# 1996             PCFX      Role-Playing     1
#                  PC        Strategy         1
#                            Simulation       1
#                  N64       Shooter          1
# 2005             PSP       Adventure        1
# Length: 1616, dtype: int64

# %% [markdown]
# ##### Seems like a lot of DS games that are either MISC or Simulation genre from 2008-2010 are missing the most of the critic_score

# %%
# looking to see if there's a pattern for the year_of_release for the NaNs in user_score
nan_user_score = games[games['user_score'].isna()]
print(nan_user_score['year_of_release'].value_counts(ascending=False))
# Out:
# 2010    457
# 2008    440
# 2011    418
# 2009    407
# 2007    376
# 1998    348
# 2006    330
# 1999    299
# 2012    290
# 2015    271
# 1997    270
# 1996    255
# 2005    235
# 2014    231
# 2013    225
# 1995    219
# 2016    206
# 2000    200
# 2002    173
# 2004    166
# 2003    164
# 2001    143
# 1994    120
# 0        94
# 1993     62
# 1981     46
# 1992     42
# 1991     41
# 1982     36
# 1986     21
# 1983     17
# 1989     17
# 1990     16
# 1987     16
# 1988     14
# 1984     14
# 1985     13
# 1980      9
# Name: year_of_release, dtype: int64

# %%
# let's try with platform
print(nan_user_score['platform'].value_counts(ascending=False))
# Out:
# PS      990
# DS      879
# PS2     680
# PSP     665
# PS3     367
# Wii     320
# N64     319
# GBA     305
# 3DS     290
# PSV     280
# SNES    239
# X360    212
# SAT     173
# PC      155
# 2600    133
# PS4     129
# NES      98
# GB       98
# XB       88
# GC       87
# XOne     54
# WiiU     42
# DC       38
# GEN      29
# NG       12
# WS        6
# SCD       6
# 3DO       3
# TG16      2
# PCFX      1
# GG        1
# Name: platform, dtype: int64

# %% [markdown]
# ##### We see that PS platform is missing the most values versus DS with critic_score

# %%
# finally, with genre
print(nan_user_score['genre'].value_counts(ascending=False))
# Out:
# Action          1163
# Misc             862
# Adventure        844
# Sports           832
# Role-Playing     725
# Fighting         411
# Racing           375
# Strategy         333
# Platform         321
# Shooter          300
# Simulation       292
# Puzzle           241
# Name: genre, dtype: int64

# %% [markdown]
# ##### It seems to me that Action has the most misisng values for both critic_score and user_score

# %%
# Count combinations of all three columns
user_result = nan_user_score.groupby(['year_of_release', 'platform', 'genre']).size()
print(user_result.sort_values(ascending=False))
# Out:
# year_of_release  platform  genre
# 2010             PSP       Adventure    62
# 2012             PSP       Action       50
# 2011             PSP       Adventure    47
# 2008             DS        Misc         46
#                            Adventure    40
#                                         ..
# 1998             SAT       Shooter       1
# 1997             PC        Adventure     1
# 1992             GEN       Adventure     1
# 2008             DS        Shooter       1
# 2016             XOne      Sports        1
# Length: 1494, dtype: int64

# %% [markdown]
# ##### For grouping year_of_release, platform, genre for missing values on user_score, we see that PSP for Adventure and Action games from 2010-2012 has the most missing values

# %% [markdown]
# ##### Let's see if we can find a pattern for tbds on user_score

# %%
# looking to see if there's a pattern for the year_of_release for the NaNs in user_score
tbd_user = games[games['user_score'] == 'tbd']
print(tbd_user['year_of_release'].value_counts(ascending=False))
# Out:
# 2009    405
# 2010    331
# 2008    326
# 2011    217
# 2002    192
# 2007    192
# 2006    124
# 2005    121
# 2004    107
# 2003     95
# 2001     82
# 0        48
# 2000     43
# 2015     38
# 2016     34
# 2012     24
# 2014     21
# 2013     15
# 1999      8
# 1997      1
# Name: year_of_release, dtype: int64

# %%
# let's try with platform
print(tbd_user['platform'].value_counts(ascending=False))
# Out:
# DS      756
# Wii     440
# GBA     262
# PS2     240
# XB      150
# PSP     123
# GC      103
# PS3      87
# X360     84
# 3DS      56
# PC       49
# PS       45
# XOne     11
# PSV       7
# PS4       6
# WiiU      5
# Name: platform, dtype: int64

# %%
# finally, with genre
print(tbd_user['genre'].value_counts(ascending=False))
# Out:
# Misc            449
# Sports          413
# Action          376
# Simulation      237
# Racing          233
# Puzzle          211
# Adventure       159
# Platform        139
# Shooter          99
# Strategy         39
# Fighting         39
# Role-Playing     30
# Name: genre, dtype: int64

# %%
# Count combinations of all three columns
tbd_result = tbd_user.groupby(['year_of_release', 'platform', 'genre']).size()
print(tbd_result.sort_values(ascending=False))
# Out:
# year_of_release  platform  genre
# 2009             DS        Simulation    53
# 2008             DS        Simulation    43
# 2010             Wii       Sports        35
# 2009             DS        Misc          34
# 2010             DS        Misc          33
#                                          ..
# 2006             PS2       Strategy       1
#                            Sports         1
#                            Shooter        1
#                            Puzzle         1
# 2016             XOne      Simulation     1
# Length: 598, dtype: int64

# %% [markdown]
# ##### We're seeing another DS Simulation games and Wii sports from 2008-2010 having the most missing values

# %%
# Check if missing data correlates with older games
missing_all_three = games[(games['critic_score'].isna()) & 
                         (games['user_score'].isna()) & 
                         (games['rating'].isna())]

print("Year distribution for games missing all three scores:")
print(missing_all_three['year_of_release'].value_counts().sort_index())
# Out:
# Year distribution for games missing all three scores:
# 0        85
# 1980      9
# 1981     46
# 1982     36
# 1983     17
# 1984     14
# 1985     13
# 1986     21
# 1987     16
# 1988     14
# 1989     17
# 1990     16
# 1991     41
# 1992     41
# 1993     62
# 1994    120
# 1995    219
# 1996    255
# 1997    268
# 1998    346
# 1999    296
# 2000    199
# 2001    142
# 2002    173
# 2003    161
# 2004    161
# 2005    232
# 2006    326
# 2007    374
# 2008    435
# 2009    402
# 2010    447
# 2011    410
# 2012    287
# 2013    222
# 2014    229
# 2015    267
# 2016    202
# Name: year_of_release, dtype: int64

# %% [markdown]
# #### Well, that's out of the question! Each year the missing values tend to grow higher. 2008 - 2011 are missing at its highest peak by having over 400 missing values!

# %%
# let's try with platform
print(missing_all_three['platform'].value_counts(ascending=False))
# Out:
# PS      983
# DS      860
# PS2     678
# PSP     663
# PS3     363
# N64     319
# Wii     313
# GBA     300
# 3DS     288
# PSV     278
# SNES    239
# X360    201
# SAT     173
# PC      142
# 2600    133
# PS4     125
# NES      98
# GB       98
# XB       87
# GC       87
# XOne     53
# WiiU     42
# DC       38
# GEN      29
# NG       12
# WS        6
# SCD       6
# 3DO       3
# TG16      2
# PCFX      1
# GG        1
# Name: platform, dtype: int64

# %%
# finally, with genre
print(missing_all_three['genre'].value_counts(ascending=False))
# Out:
# Action          1151
# Misc             856
# Adventure        831
# Sports           821
# Role-Playing     718
# Fighting         409
# Racing           364
# Strategy         331
# Platform         319
# Shooter          298
# Simulation       288
# Puzzle           233
# Name: genre, dtype: int64

# %%
# Count combinations of all three columns
missing_all_three_results = missing_all_three.groupby(['year_of_release', 'platform', 'genre']).size()
print(missing_all_three_results.sort_values(ascending=False))
# Out:
# year_of_release  platform  genre
# 2010             PSP       Adventure       62
# 2012             PSP       Action          50
# 2011             PSP       Adventure       47
# 2008             DS        Misc            46
#                            Adventure       40
#                                            ..
# 2007             PS3       Role-Playing     1
#                            Shooter          1
# 1992             SNES      Adventure        1
# 2007             Wii       Puzzle           1
# 2016             XOne      Sports           1
# Length: 1479, dtype: int64

# %% [markdown]
# ## Possible reasons why the values are missing:
#
# ### Volume effect:
# - More games are being released each year, so more games might be slipping through the cracks
# ### Market saturation:
# - With so many games, not all get reviewed
# ### Platform diversification:
# - New platforms might have different review coverage
#
# ### Indie/smaller games:
# - The rise of digital distribution might mean more smaller games that don't get mainstream coverage

# %%
# Handle missing values based on analysis
# Your code here to handle missing values according to your strategy
# Let's see what the sales for the missing values for each column 
# and when you group them with year_of_release, platofrm, and genre

# Let's start with missing values for critic_score by year. 
total_nan_critic_sales_year = nan_critic_score.groupby('year_of_release')['na_sales','eu_sales','jp_sales','other_sales'].sum()
total_nan_critic_sales_year['total_sales'] = (total_nan_critic_sales_year['na_sales'] + total_nan_critic_sales_year['eu_sales']
                                              + total_nan_critic_sales_year['jp_sales'] + total_nan_critic_sales_year['other_sales'])
display(total_nan_critic_sales_year)
# Out:
#                  na_sales  eu_sales  jp_sales  other_sales  total_sales
# year_of_release
# 0                   17.21      4.25      5.27         1.45        28.18
# 1980                10.59      0.67      0.00         0.12        11.38
# 1981                33.40      1.96      0.00         0.32        35.68
# 1982                26.92      1.65      0.00         0.31        28.88
# 1983                 7.76      0.80      8.10         0.14        16.80
# 1984                33.28      2.10     14.27         0.70        50.35
# 1985                33.73      4.71     14.56         0.91        53.91
# 1986                12.50      2.84     19.81         1.93        37.08
# 1987                 8.46      1.41     11.63         0.20        21.70
# 1988                23.87      6.57     15.76         0.98        47.18
# 1989                45.15      8.44     18.36         1.50        73.45
# 1990                25.46      7.63     14.88         1.40        49.37
# ...

# %%
# Let's make a graph to see a pattern throughout the year

# Filter out year 0 for cleaner visualization
filtered_data = total_nan_critic_sales_year[total_nan_critic_sales_year.index != 0]
filtered_data.plot(xlim = [1980,2020])
plt.title("Sales for missing critic ratings")
plt.xlabel('Years')
plt.ylabel('Sales $ (in Millions')
plt.show()

# %% [markdown]
# ##### We noticed an inverse relationship with jp_sales compared to the other region sales between 1995 and 2000
# ##### Also noticed that sales drastically increased in 2015, we're not sure how 2016 would look like since the data is incomplete.

# %%
# Now, let's look at the sales for missing value in critic_score for each platform. 
total_nan_critic_sales_platform = nan_critic_score.groupby('platform')['na_sales','eu_sales','jp_sales','other_sales'].sum()
total_nan_critic_sales_platform['total_sales'] = (total_nan_critic_sales_platform['na_sales'] + total_nan_critic_sales_platform['eu_sales']
+ total_nan_critic_sales_platform['jp_sales'] + total_nan_critic_sales_platform['other_sales'])
display(total_nan_critic_sales_platform.sort_values('total_sales',ascending=False))
# Out:
#           na_sales  eu_sales  jp_sales  other_sales  total_sales
# platform
# PS          231.44    139.70     98.58        27.85       497.57
# DS          175.29     79.87     88.82        25.17       369.15
# PS2          86.51     66.08     62.12        42.66       257.37
# GB          114.32     47.82     85.12         8.20       255.46
# NES         125.94     21.15     98.65         5.31       251.05
# N64         139.02     41.06     34.22         4.38       218.68
# Wii         128.21     49.96     16.50        16.34       211.01
# SNES         61.23     19.04    116.55         3.22       200.04
# GBA          80.96     32.97     30.29         3.50       147.72
# PS3          45.56     52.47     24.77        19.18       141.98
# 3DS          34.12     27.73     66.65         5.60       134.10
# X360         57.93     33.14      2.25         9.02       102.34
# 2600         90.60      5.47      0.00         0.91        96.98
# ...

# %% [markdown]
# ##### Looking at the table above, PCFX, GG, 3D0, etc has very low sales compared to other popular consoles like PS, DS, PS2.

# %%
# Lastly, let's look at missing values for critic_score for Genre 
total_nan_critic_sales_genre = nan_critic_score.groupby('genre')['na_sales','eu_sales','jp_sales','other_sales'].sum()
total_nan_critic_sales_genre['total_sales'] = (total_nan_critic_sales_genre['na_sales'] + total_nan_critic_sales_genre['eu_sales']
+ total_nan_critic_sales_genre['jp_sales'] + total_nan_critic_sales_genre['other_sales'])
display(total_nan_critic_sales_genre.sort_values('total_sales',ascending=False))
# Out:
#               na_sales  eu_sales  jp_sales  other_sales  total_sales
# genre
# Action          245.49    110.75     83.13        31.66       471.03
# Sports          189.57    112.75    100.29        35.17       437.78
# Platform        240.14     86.99     87.52        17.76       432.41
# Role-Playing    109.44     68.81    231.82        18.97       429.04
# Misc            158.50     80.58     74.69        28.26       342.03
# Shooter         136.46     52.34     20.13        15.17       224.10
# Racing          114.85     62.34     27.83        15.31       220.33
# Fighting         83.75     38.35     59.54        10.85       192.49
# Simulation       83.36     43.11     34.96        12.50       173.93
# Puzzle           76.39     20.11     41.38         4.64       142.52
# Adventure        56.77     33.99     43.10         7.49       141.35
# Strategy         33.65     18.99     45.19         4.06       101.89

# %% [markdown]
# ##### We see that Action, Sports, and Platform are the top 3 genre for missing values in critc_score columns

# %%
# Now let's see when we group all three columns for the missing critc_score column

# Count combinations of sales of missing critic_score on all three columns
total_nan_critic_sales = nan_critic_score.groupby(['genre','platform','year_of_release'])['na_sales','eu_sales','jp_sales','other_sales'].sum()
total_nan_critic_sales['total_sales'] = (total_nan_critic_sales['na_sales'] + total_nan_critic_sales['eu_sales'] + total_nan_critic_sales['jp_sales']
                                        + total_nan_critic_sales['other_sales'])
display(total_nan_critic_sales)
# Out:
#                                    na_sales  eu_sales  jp_sales  other_sales  \
# genre    platform year_of_release
# Action   2600     0                    2.76      0.17      0.00         0.01
#                   1980                 0.32      0.02      0.00         0.00
#                   1981                13.86      0.81      0.00         0.12
#                   1982                 6.07      0.38      0.00         0.05
#                   1983                 2.67      0.17      0.00         0.02
# ...                                     ...       ...       ...          ...
# Strategy X360     2010                 0.17      0.04      0.02         0.02
#          XB       2003                 0.12      0.03      0.00         0.01
#                   2004                 0.23      0.07      0.00         0.01
#                   2005                 0.11      0.03      0.00         0.01
#          XOne     2015                 0.14      0.05      0.00         0.02
#
# ...

# %%
# Calculate total sales for missing values for critic_score columns
nan_critic_score = nan_critic_score.copy()
nan_critic_score['total_sales'] = (nan_critic_score['na_sales'] + nan_critic_score['eu_sales'] + nan_critic_score['jp_sales'] + nan_critic_score['other_sales'])
display(nan_critic_score)
# Out:
#                                 name platform  year_of_release         genre  \
# 1                  Super Mario Bros.      NES             1985      Platform
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                             Tetris       GB             1989        Puzzle
# 9                          Duck Hunt      NES             1984       Shooter
# 10                        Nintendogs       DS             2005    Simulation
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %%
# group platform and year to calculate total sales for the missing values in critic_score
platform_year = nan_critic_score.groupby(['platform','year_of_release'])['na_sales','eu_sales','jp_sales','other_sales'].sum()
platform_year['total_sales'] = (platform_year['na_sales'] + platform_year['eu_sales'] + platform_year['jp_sales'] + platform_year['other_sales'])
display(platform_year)
# Out:
#                           na_sales  eu_sales  jp_sales  other_sales  \
# platform year_of_release
# 2600     0                    9.82      0.61      0.00         0.07
#          1980                10.59      0.67      0.00         0.12
#          1981                33.40      1.96      0.00         0.32
#          1982                26.92      1.65      0.00         0.31
#          1983                 5.44      0.34      0.00         0.06
# ...                            ...       ...       ...          ...
# XB       2008                 0.13      0.04      0.00         0.01
# XOne     2013                 2.53      1.14      0.00         0.37
#          2014                 4.07      2.34      0.01         0.64
#          2015                 9.09      4.99      0.04         1.39
#          2016                 1.32      0.79      0.00         0.20
#
#                           total_sales
# platform year_of_release
# 2600     0                      10.50
# ...

# %%
# group platform and genre for total sales on missing values on critic_score column
platform_genre = nan_critic_score.groupby(['platform','genre'])['na_sales','eu_sales','jp_sales','other_sales'].sum()
platform_genre['total_sales'] = platform_genre['na_sales'] + platform_genre['eu_sales'] + platform_genre['jp_sales']+ platform_genre['other_sales']

display(platform_genre)
# Out:
#                        na_sales  eu_sales  jp_sales  other_sales  total_sales
# platform genre
# 2600     Action           27.39      1.64      0.00         0.22        29.25
#          Adventure         1.59      0.10      0.00         0.01         1.70
#          Fighting          1.16      0.07      0.00         0.01         1.24
#          Misc              3.34      0.20      0.00         0.03         3.57
#          Platform         12.38      0.72      0.00         0.16        13.26
# ...                         ...       ...       ...          ...          ...
# XOne     Role-Playing      1.11      0.68      0.00         0.18         1.97
#          Shooter           7.23      3.77      0.03         1.10        12.13
#          Simulation        0.28      0.23      0.00         0.05         0.56
#          Sports            0.06      0.08      0.00         0.01         0.15
#          Strategy          0.14      0.05      0.00         0.02         0.21
#
# ...

# %%
# group year_of_release and genre to calculate sales on missing values on critic_score column
year_genre = nan_critic_score.groupby(['year_of_release','genre'])['na_sales','eu_sales','jp_sales','other_sales'].sum()
year_genre['total_sales'] = year_genre['na_sales'] + year_genre['eu_sales'] + year_genre['jp_sales']+ year_genre['other_sales']
display(year_genre)
# Out:
#                               na_sales  eu_sales  jp_sales  other_sales  \
# year_of_release genre
# 0               Action            4.07      0.57      0.65         0.16
#                 Adventure         1.50      0.08      0.06         0.04
#                 Fighting          2.16      1.07      0.20         0.42
#                 Misc              0.97      0.40      1.09         0.15
#                 Platform          0.69      0.31      0.12         0.04
# ...                                ...       ...       ...          ...
# 2016            Role-Playing      4.12      2.57      5.51         0.84
#                 Shooter           1.24      1.31      0.02         0.39
#                 Simulation        0.02      0.04      0.33         0.00
#                 Sports            0.67      1.27      0.62         0.27
#                 Strategy          0.00      0.02      0.23         0.00
#
#                               total_sales
# year_of_release genre
# ...

# %% [markdown]
# ##### ok so we noticed on the last few df, jp_sales was zero but we have data for jp_sales when grouping year_of_release and genre for missing values in critic_score

# %%
# calculate the total sales for missing values for user_score
nan_user_score = nan_user_score.copy()
nan_user_score['total_sales'] = nan_user_score['na_sales'] + nan_user_score['eu_sales'] + nan_user_score['jp_sales'] + nan_user_score['other_sales']
display(nan_user_score.sort_values('total_sales',ascending=False))
# Out:
#                                                    name platform  \
# 1                                     Super Mario Bros.      NES
# 4                              Pokemon Red/Pokemon Blue       GB
# 5                                                Tetris       GB
# 9                                             Duck Hunt      NES
# 10                                           Nintendogs       DS
# ...                                                 ...      ...
# 16241                                            NHL 16      PS3
# 16236                     Game Book DS: Sword World 2.0       DS
# 16714                               Winning Post 8 2016      PSV
# 16676                                  G1 Jockey 4 2008      PS3
# 16709  SCORE International Baja 1000: The Official Game      PS2
#
#        year_of_release         genre  na_sales  eu_sales  jp_sales  \
# 1                 1985      Platform     29.08      3.58      6.81
# ...

# %%
# calculate total sales for missing values in user_score by year
nan_user_score_year = nan_user_score.groupby('year_of_release')['na_sales','eu_sales','jp_sales','other_sales'].sum()
nan_user_score_year['total_sales'] = (nan_user_score_year['na_sales'] + nan_user_score_year['eu_sales'] + nan_user_score_year['jp_sales']
                                      + nan_user_score_year['other_sales'])
display(nan_user_score_year)
# Out:
#                  na_sales  eu_sales  jp_sales  other_sales  total_sales
# year_of_release
# 0                   14.87      3.78      5.27         1.17        25.09
# 1980                10.59      0.67      0.00         0.12        11.38
# 1981                33.40      1.96      0.00         0.32        35.68
# 1982                26.92      1.65      0.00         0.31        28.88
# 1983                 7.76      0.80      8.10         0.14        16.80
# 1984                33.28      2.10     14.27         0.70        50.35
# 1985                33.73      4.71     14.56         0.91        53.91
# 1986                12.50      2.84     19.81         1.93        37.08
# 1987                 8.46      1.41     11.63         0.20        21.70
# 1988                23.87      6.57     15.76         0.98        47.18
# 1989                45.15      8.44     18.36         1.50        73.45
# 1990                25.46      7.63     14.88         1.40        49.37
# ...

# %%
# graph the sales by year for missing values for user_score column
nan_user_score_year.plot(xlim=[1980,2020])
plt.title('Sales for missing values in user_score')
plt.xlabel('Year')
plt.ylabel('Sales $ (in millions)')
plt.show()

# %% [markdown]
# ##### It looks like the same graph as the missing values for critic_score

# %%
# calculate sales by platform for missing values in user_score
nan_user_score_platform = nan_user_score.groupby('platform')['na_sales','eu_sales','jp_sales','other_sales'].sum()
nan_user_score_platform['total_sales'] = (nan_user_score_platform['na_sales'] + nan_user_score_platform['eu_sales'] + nan_user_score_platform['jp_sales'] 
                                          + nan_user_score_platform['other_sales'])
display(nan_user_score_platform.sort_values('total_sales',ascending=False))
# Out:
#           na_sales  eu_sales  jp_sales  other_sales  total_sales
# platform
# PS          233.89    140.27     99.29        27.95       501.40
# GB          114.32     47.82     85.12         8.20       255.46
# NES         125.94     21.15     98.65         5.31       251.05
# DS           87.02     52.78     88.42        14.49       242.71
# N64         139.02     41.06     34.22         4.38       218.68
# SNES         61.23     19.04    116.55         3.22       200.04
# PS2          57.89     47.03     60.80        26.79       192.51
# GBA          67.25     26.71     30.32         2.99       127.27
# 3DS          30.35     24.95     66.48         5.08       126.86
# Wii          44.66     29.17     16.14         7.54        97.51
# 2600         90.60      5.47      0.00         0.91        96.98
# PS3          25.44     34.56     20.45        12.20        92.65
# PSP          11.07     11.50     50.87         5.58        79.02
# ...

# %%
# calculate total sales by genre for missing values in user_score column
nan_user_score_genre = nan_user_score.groupby('genre')['na_sales','eu_sales','jp_sales','other_sales'].sum()
nan_user_score_genre['total_sales'] = (nan_user_score_genre['na_sales'] + nan_user_score_genre['eu_sales'] + nan_user_score_genre['jp_sales'] 
                                          + nan_user_score_genre['other_sales'])
display(nan_user_score_genre.sort_values('total_sales',ascending=False))
# Out:
#               na_sales  eu_sales  jp_sales  other_sales  total_sales
# genre
# Role-Playing    106.43     67.57    230.20        18.26       422.46
# Platform        228.31     80.66     87.51        15.79       412.27
# Action          199.36     87.71     80.86        21.51       389.44
# Sports          127.65     84.86     97.91        21.13       331.55
# Misc            100.43     64.50     74.16        20.65       259.74
# Racing          102.34     59.29     27.79        12.55       201.97
# Shooter         123.66     44.50     19.61        12.47       200.24
# Fighting         80.84     36.88     58.92         9.59       186.23
# Puzzle           67.98     16.95     41.52         3.60       130.05
# Simulation       42.15     27.34     35.54         6.75       111.78
# Adventure        36.38     25.06     43.03         4.47       108.94
# Strategy         27.05     16.39     45.17         3.46        92.07

# %%
# Calculate combinations of sales of missing user_score on all three columns
total_nan_user_sales = nan_user_score.groupby(['genre','platform','year_of_release'])['na_sales','eu_sales','jp_sales','other_sales'].sum()
total_nan_user_sales['total_sales'] = (total_nan_user_sales['na_sales'] + total_nan_user_sales['eu_sales'] + total_nan_user_sales['jp_sales']
                                        + total_nan_user_sales['other_sales'])
display(total_nan_user_sales)
# Out:
#                                    na_sales  eu_sales  jp_sales  other_sales  \
# genre    platform year_of_release
# Action   2600     0                    2.76      0.17      0.00         0.01
#                   1980                 0.32      0.02      0.00         0.00
#                   1981                13.86      0.81      0.00         0.12
#                   1982                 6.07      0.38      0.00         0.05
#                   1983                 2.67      0.17      0.00         0.02
# ...                                     ...       ...       ...          ...
# Strategy X360     2010                 0.08      0.04      0.02         0.01
#          XB       2003                 0.12      0.03      0.00         0.01
#                   2004                 0.23      0.07      0.00         0.01
#                   2005                 0.11      0.03      0.00         0.01
#          XOne     2015                 0.14      0.05      0.00         0.02
#
# ...

# %% [markdown]
# ##### It seems like jp_sales is the same pattern for sales of missing of combined columns for missing values for critic_score. It's weird to see jp_sales has sales when by each column individually but not when you group them together.

# %%
#Calculate total jp_sales for combinations of three columns for missing user_score. 
total_jp_sales = total_nan_user_sales['jp_sales'].sum()
print(f"Total JP sales for games with missing user scores: {total_jp_sales}")

print()

# Total jp_sales by genre
jp_by_genre = total_nan_user_sales.groupby(['genre','platform','year_of_release'])['jp_sales'].sum()
print("JP sales by genre:")
display(jp_by_genre)

print()

# Look at non-zero combinations
non_zero_sales = jp_by_genre[jp_by_genre > 0]
print(f"Number of combinations with actual sales: {len(non_zero_sales)}")

print()

display(non_zero_sales)

print()

total_from_grouped = jp_by_genre.sum()
print(f"Total from grouped data: {total_from_grouped}")
# Out:
# Total JP sales for games with missing user scores: 842.22
#
# JP sales by genre:
# genre     platform  year_of_release
# Action    2600      0                  0.00
#                     1980               0.00
#                     1981               0.00
#                     1982               0.00
#                     1983               0.00
#                                        ...
# Strategy  X360      2010               0.02
#           XB        2003               0.00
#                     2004               0.00
#                     2005               0.00
#           XOne      2015               0.00
# Name: jp_sales, Length: 1494, dtype: float64
# Number of combinations with actual sales: 1087
# genre     platform  year_of_release
# Action    3DS       2011               1.00
#                     2012               1.78
#                     2013               1.53
#                     2014               0.78
#                     2015               7.80
# ...

# %% [markdown]
# ##### Even though we see jp_sales being zero when grouping, there's still 842.25 in sales for missing user scores. The data that shows zero is platform 2600 was American made and didn't had the presence in Japan in the 1980s. Japan sales hit big if they're Nintendo brands which explains their sales for 3DS and Wii.
#
# ##### https://www.cnbc.com/2019/10/08/why-microsoft-xbox-isnt-as-popular-in-japan-as-sonys-playstation.html here is a link for reference that Japan is not big on Microsoft consoles such as Xbox which is why you would see 0 sales on XB and Xbox 1

# %%
# calculate sales for missing values for tbd_users
tbd_user = tbd_user.copy()
tbd_user['total_sales'] = tbd_user['na_sales'] + tbd_user['eu_sales'] + tbd_user['jp_sales'] + tbd_user['other_sales']
display(tbd_user)
print()
total_jp_sales = tbd_user['jp_sales'].sum()
total_sales_tbd = tbd_user['total_sales'].sum()
print(f"Total japan_sales with tbd ratings is: {total_jp_sales: .2f}")
print(f"The total sales for all regions for tbd ratins is: {total_sales_tbd: .2f}")
# Out:
#                                            name platform  year_of_release  \
# 119                               Zumba Fitness      Wii             2010
# 301              Namco Museum: 50th Anniversary      PS2             2005
# 520                             Zumba Fitness 2      Wii             2011
# 645                                uDraw Studio      Wii             2010
# 657    Frogger's Adventures: Temple of the Frog      GBA                0
# ...                                         ...      ...              ...
# 16695                           Planet Monsters      GBA             2001
# 16697                          Bust-A-Move 3000       GC             2003
# 16698                          Mega Brain Boost       DS             2008
# 16704                                  Plushees       DS             2008
# 16706             Men in Black II: Alien Escape       GC             2003
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# ...

# %% [markdown]
# ##### so we know there's 6.61 sales in Japan region but wondering why GBA, Wii, PS2, GC, DS etc. are showing 0 sales.

# %%
# look at the jp_sales for tbd_ratings
non_zero_tbd_jp = tbd_user[tbd_user['jp_sales'] > 0]
display(non_zero_tbd_jp)
# Out:
#                                                     name platform  \
# 821                                      The Incredibles      GBA
# 1089                                      Monsters, Inc.      GBA
# 1199                                      MySims Kingdom       DS
# 1862                                       NBA Live 2001      PS2
# 2043   Disney Fairies: Tinker Bell and the Lost Treasure       DS
# ...                                                  ...      ...
# 16266                                Shepherd's Crossing      PSP
# 16301                                          Caladrius     X360
# 16364         Nitroplus Blasterz: Heroines Infinite Duel      PS3
# 16507                             World Heroes Anthology      PS2
# 16647                        Metal Gear Solid HD Edition     X360
#
#        year_of_release       genre  na_sales  eu_sales  jp_sales  other_sales  \
# 821               2004      Action      1.15      0.77      0.04         0.10
# ...

# %% [markdown]
# ##### Not sure why there's there's 0 sales for the most popular consoles in Japan so let's start by each category!

# %%
# calculate sales for tbd ratings by yearly_release
tbd_user_year = tbd_user.groupby('year_of_release')['na_sales','eu_sales','jp_sales','other_sales'].sum()
tbd_user_year['total_sales'] = (tbd_user_year['na_sales'] + tbd_user_year['eu_sales']
                                + tbd_user_year['jp_sales'] + tbd_user_year['other_sales'])
display(tbd_user_year)
# Out:
#                  na_sales  eu_sales  jp_sales  other_sales  total_sales
# year_of_release
# 0                    7.27      1.72      0.00         0.66         9.65
# 1997                 0.03      0.02      0.00         0.00         0.05
# 1999                 3.25      0.88      0.00         0.15         4.28
# 2000                 7.31      5.15      0.32         1.14        13.92
# 2001                12.07      6.51      0.28         1.23        20.09
# 2002                16.97      7.11      0.25         1.12        25.45
# 2003                 9.80      4.03      0.00         0.67        14.50
# 2004                14.93      5.98      0.46         0.81        22.18
# 2005                12.92      4.81      0.18         1.08        18.99
# 2006                10.17      2.58      1.39         1.10        15.24
# 2007                29.24      8.89      0.91         3.94        42.98
# 2008                46.92     15.30      0.55         7.95        70.72
# ...

# %%
# let's plot the graph for the sales by year_of_release for tbd ratings
tbd_user_year.plot(xlim=[1995,2020])
plt.title("Sales for TBD ratings")
plt.xlabel("Year")
plt.ylabel('Sales $ (in millions)')
plt.show()

# %% [markdown]
# ##### We see that jp_sales for tbd ratings is very flat from 1997 - 2016

# %%
# calculate sales by platform for tbd ratings
tbd_user_platform = tbd_user.groupby('platform')['na_sales','eu_sales','jp_sales','other_sales'].sum()
tbd_user_platform['total_sales'] = (tbd_user_platform['na_sales'] + tbd_user_platform['eu_sales']
                                + tbd_user_platform['jp_sales'] + tbd_user_platform['other_sales'])
display(tbd_user_platform.sort_values('total_sales',ascending=False))
# Out:
#           na_sales  eu_sales  jp_sales  other_sales  total_sales
# platform
# DS          102.47     31.20      3.48        11.97       149.12
# Wii          75.00     17.16      0.43         7.78       100.37
# PS2          29.93     22.30      0.79        10.82        63.84
# GBA          36.32     13.79      0.84         0.98        51.93
# PSP          10.81      3.26      0.32         2.54        16.93
# XB           12.49      3.46      0.00         0.38        16.33
# PS            7.60      5.12      0.00         0.90        13.62
# X360          9.97      1.58      0.04         0.99        12.58
# GC            8.91      2.24      0.00         0.22        11.37
# PS3           6.33      2.33      0.37         1.22        10.25
# 3DS           2.78      1.50      0.23         0.34         4.85
# PC            2.26      1.08      0.00         0.17         3.51
# XOne          0.35      0.16      0.00         0.04         0.55
# ...

# %% [markdown]
# ##### we see that best jp_sales is the DS platform

# %%
# calculate sales by genre for tbd ratings
tbd_user_genre = tbd_user.groupby('genre')['na_sales','eu_sales','jp_sales','other_sales'].sum()
tbd_user_genre['total_sales'] = (tbd_user_genre['na_sales'] + tbd_user_genre['eu_sales']
                                + tbd_user_genre['jp_sales'] + tbd_user_genre['other_sales'])
display(tbd_user_genre.sort_values('total_sales',ascending=False))
# Out:
#               na_sales  eu_sales  jp_sales  other_sales  total_sales
# genre
# Misc             67.76     21.44      0.71         9.91        99.82
# Sports           55.77     19.31      0.87         7.15        83.10
# Action           45.92     16.59      1.29         5.81        69.61
# Simulation       38.81     11.53      1.34         4.91        56.59
# Racing           23.98      7.93      0.31         2.93        35.15
# Adventure        21.32      8.14      0.48         2.49        32.43
# Puzzle           20.47      8.66      0.81         2.30        32.24
# Platform         18.52      7.44      0.22         1.58        27.76
# Shooter           5.58      1.60      0.01         0.44         7.63
# Fighting          3.52      1.68      0.09         0.45         5.74
# Role-Playing      2.25      0.55      0.36         0.29         3.45
# Strategy          1.65      0.62      0.12         0.19         2.58

# %%
# calculate sales by year and platform for tbd ratings

tbd_user_plat_year = tbd_user.groupby(['platform','year_of_release'])['na_sales','eu_sales','jp_sales','other_sales'].sum()
tbd_user_plat_year['total_sales'] = (tbd_user_plat_year['na_sales'] + tbd_user_plat_year['eu_sales']
                                + tbd_user_plat_year['jp_sales'] + tbd_user_plat_year['other_sales'])
display(tbd_user_plat_year)
# Out:
#                           na_sales  eu_sales  jp_sales  other_sales  \
# platform year_of_release
# 3DS      0                    0.26      0.00      0.00         0.02
#          2011                 1.86      0.50      0.12         0.19
#          2012                 0.17      0.15      0.00         0.03
#          2013                 0.08      0.15      0.00         0.02
#          2014                 0.22      0.36      0.06         0.05
# ...                            ...       ...       ...          ...
# XB       2004                 2.44      0.70      0.00         0.08
#          2005                 1.95      0.58      0.00         0.05
#          2006                 0.61      0.16      0.00         0.01
# XOne     2015                 0.17      0.03      0.00         0.02
#          2016                 0.18      0.13      0.00         0.02
#
#                           total_sales
# platform year_of_release
# 3DS      0                       0.28
# ...

# %%
# Calculate sales by year and genre for tbd ratings
tbd_user_year_genre = tbd_user.groupby(['genre','year_of_release'])['na_sales','eu_sales','jp_sales','other_sales'].sum()
tbd_user_year_genre['total_sales'] = (tbd_user_year_genre['na_sales'] + tbd_user_year_genre['eu_sales']
                                + tbd_user_year_genre['jp_sales'] + tbd_user_year_genre['other_sales'])
display(tbd_user_year_genre)
# Out:
#                           na_sales  eu_sales  jp_sales  other_sales  \
# genre    year_of_release
# Action   0                    0.97      0.48      0.00         0.15
#          2000                 0.67      0.45      0.00         0.07
#          2001                 1.11      0.42      0.00         0.03
#          2002                 2.79      1.05      0.00         0.10
#          2003                 2.70      0.97      0.00         0.07
# ...                            ...       ...       ...          ...
# Strategy 2007                 0.14      0.01      0.05         0.02
#          2008                 0.25      0.01      0.02         0.03
#          2009                 0.48      0.16      0.00         0.06
#          2010                 0.40      0.29      0.02         0.06
#          2011                 0.05      0.02      0.00         0.01
#
#                           total_sales
# genre    year_of_release
# Action   0                       1.60
# ...

# %%
# Calculate sales for platform, year, genre for tbd ratings
tbd_user_all_3 = tbd_user.groupby(['genre','platform','year_of_release'])['na_sales','eu_sales','jp_sales','other_sales'].sum()
tbd_user_all_3['total_sales'] = (tbd_user_all_3['na_sales'] + tbd_user_all_3['eu_sales']
                                + tbd_user_all_3['jp_sales'] + tbd_user_all_3['other_sales'])
display(tbd_user_all_3)
print()
total_all_3_sales = tbd_user_all_3['total_sales'].sum()
print(f"the total sales for 3 categories from tbd ratings are {total_all_3_sales: .2f}")
# Out:
#                                    na_sales  eu_sales  jp_sales  other_sales  \
# genre    platform year_of_release
# Action   3DS      2011                 0.25      0.04      0.00         0.03
#                   2012                 0.03      0.00      0.00         0.00
#                   2013                 0.03      0.05      0.00         0.01
#                   2014                 0.01      0.08      0.00         0.00
#                   2015                 0.10      0.29      0.04         0.02
# ...                                     ...       ...       ...          ...
# Strategy Wii      2009                 0.07      0.00      0.00         0.00
#                   2010                 0.24      0.13      0.00         0.03
#          XB       2003                 0.08      0.03      0.00         0.00
#                   2004                 0.07      0.02      0.00         0.00
#                   2006                 0.03      0.01      0.00         0.00
#
# ...

# %% [markdown]
# ##### knowing that there's that much of sales for tbd ratings based on the three categories (genre, platform, and year_of_release) we will keep it as tbds. If we have to calculate the criti_score and user_score we can do a pd.to_numeric(df,errors='coerce')

# %% [markdown]
# #### Why do you think the values are missing? Give possible reasons?
# - The reasons I think there are missing values in the data are because:
#     - Incomplete Data at the Time of Collection
#         - Instructions state that Year 2016 is incomplete so it's because for the scores and ratings because it hadn't received enough user review at the time the data was recorded
#     - Data is old:
#         - When Data is old, sometimes it misses data. For an example: If this data was originally in MS Excel from the 90s, converting it to MS 2017 could lead to a lot of data missing.
#         - Different data sources:
#             - it's possible that dataset combines info from multiple sources. There could had been an error when merging websites or databases.
#         - Platform-speciic issues:
#             - I realized that older platforms like PS NES, SNES missing a good amount of ratings

# %% [markdown]
# ### Explain why you filled in the missing values as you did or why you decided to leave them blank
# - I left the critic_score, user_score, and ratings as it is.
#
# ### Reasons for critic_score and user_score:
# - it would hurt the average when doing a hypothesis testing. We definitely don't want to exclude them since it involes a chunk of sales. It's best just to leave it alone.
#
# ### Reasons for rating:
# - I left it blank because there's no need to calculate the average on Rating. We can just do a dropna on the rating further down the road. We could be 'tbd' but I don't think it'll do much of a difference.

# %% [markdown]
# <div style="border: 5px solid green; padding: 10px; margin: 5px">
# <b> Reviewer's comment</b>
#
# Agreed.
#
# </div>

# %% [markdown]
# ### 2.4 Calculate Total Sales

# %%
# Calculate total sales across all regions and put them in a different column
games['total_sales'] = games['na_sales'] + games['eu_sales'] + games['jp_sales'] + games['other_sales']
display(games.head())
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating  \
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN
#
#    total_sales
# 0        82.54
# 1        40.24
# 2        35.52
# 3        32.77
# ...

# %% [markdown]
# # Step 3: Analyzing Video Game Sales Data
#
# ## 3.1 Temporal Analysis of Game Releases
# Let's first examine the distribution of game releases across different years to understand our data's coverage and significance:

# %%
# Create a DataFrame with game releases by year
yearly_release = games.groupby('year_of_release').size()

# %%
# Visualize the distribution of games across years
print(yearly_release.sort_values(ascending=False))
# Out:
# year_of_release
# 2008    1427
# 2009    1426
# 2010    1255
# 2007    1197
# 2011    1136
# 2006    1006
# 2005     939
# 2002     829
# 2003     775
# 2004     762
# 2012     653
# 2015     606
# 2014     581
# 2013     544
# 2016     502
# 2001     482
# 1998     379
# 2000     350
# 1999     338
# 1997     289
# 0        269
# 1996     263
# 1995     219
# 1994     121
# 1993      62
# 1981      46
# 1992      43
# 1991      41
# 1982      36
# 1986      21
# 1989      17
# 1983      17
# 1987      16
# 1990      16
# 1988      15
# 1985      14
# 1984      14
# 1980       9
# dtype: int64

# %%
yearly_release.plot(xlim=[1980,2020])
plt.title("Distrubition of Games")
plt.xlabel('Year')
plt.ylabel('# of games released')
plt.show()

# %% [markdown]
# ##### 2006-2011 were the highest peaks for new video games then in 2012 and later, the amount of releases had a big drop

# %% [markdown]
# <div style="border: 5px solid green; padding: 10px; margin: 5px">
# <b> Reviewer's comment</b>
#
# Good.
#
# </div>

# %%
# Display summary statistics for each year
avg_release  = games.groupby('year_of_release')['na_sales','eu_sales','jp_sales','other_sales'].agg(['mean','var','std','sum','count'])
display(avg_release)

# graph a line chart to look at the sales average for each year
avg_sales_release = games.groupby('year_of_release')['na_sales','eu_sales','jp_sales','other_sales'].agg('mean')

avg_sales_release.plot(xlim=[1980,2020])
plt.show()

print()

# Show a graph of the total sales by each year

total_sales_release = games.groupby('year_of_release')['na_sales','eu_sales','jp_sales','other_sales'].agg('sum')
total_sales_release.plot(xlim=[1980,2020])
plt.show()
# Out:
#                  na_sales                                     eu_sales  \
#                      mean        var       std     sum count      mean
# year_of_release
# 0                0.219888   0.180546  0.424907   59.15   269  0.090929
# 1980             1.176667   1.645125  1.282624   10.59     9  0.074444
# 1981             0.726087   0.534193  0.730885   33.40    46  0.042609
# 1982             0.747778   1.374166  1.172248   26.92    36  0.045833
# 1983             0.456471   0.077787  0.278903    7.76    17  0.047059
# 1984             2.377143  50.265053  7.089785   33.28    14  0.150000
# 1985             2.409286  59.125469  7.689309   33.73    14  0.338571
# 1986             0.595238   0.777116  0.881542   12.50    21  0.135238
# 1987             0.528750   0.426532  0.653094    8.46    16  0.088125
# 1988             1.591333   6.917712  2.630154   23.87    15  0.439333
# 1989             2.655882  34.735938  5.893720   45.15    17  0.496471
# ...

# %% [markdown]
# ##### We noticed an inverse relationship with jp_sales compared to the other region sales between 1995 and 2000

# %% [markdown]
# ### Questions to Consider:
# - Which years show significant numbers of game releases?
#     - 2006-2001 showed the highest peak for the numbers of releases.
# - Are there any notable trends or patterns in the number of releases?
#     - 2012 dropped drastically and it gradually decreased over time due to gamers can buy the games on Xbox store, PS4 online shop, amazon, etc.
# - Is there enough recent data to make predictions for 2017?
#     - I believe the numer of release is going to drop down from 2016 by looking at the graph; you can see the number of release is gradually decreasing. Despite having a little increase in 2015, it looks like # of releases are going to decrease
#
# ### A few things consider:
# - highest average of sales were in 1985-1990 due to the fewer total releases.
# - low average of sales were in 2006-2011 since the great amount of releases happened during those years.
# - For total sales by each year, the highest sales were when the peak of number of releases during the 2006-2011 period.

# %% [markdown]
# ## 3.2 Platform Sales Analysis Over Time
#
# Now let's analyze how sales vary across platforms and years:

# %%
# Calculate total sales by platform and year
plat_year = games.groupby(['platform','year_of_release'])['na_sales','eu_sales','jp_sales','other_sales'].sum()
plat_year['total_sales'] = plat_year['na_sales'] + plat_year['eu_sales'] + plat_year['jp_sales'] + plat_year['other_sales']
display(plat_year)
# Out:
#                           na_sales  eu_sales  jp_sales  other_sales  \
# platform year_of_release
# 2600     0                    9.82      0.61      0.00         0.07
#          1980                10.59      0.67      0.00         0.12
#          1981                33.40      1.96      0.00         0.32
#          1982                26.92      1.65      0.00         0.31
#          1983                 5.44      0.34      0.00         0.06
# ...                            ...       ...       ...          ...
# XB       2008                 0.13      0.04      0.00         0.01
# XOne     2013                11.85      5.34      0.02         1.75
#          2014                30.97     18.15      0.14         4.81
#          2015                36.03     18.47      0.17         5.47
#          2016                14.27      9.63      0.01         2.24
#
#                           total_sales
# platform year_of_release
# 2600     0                      10.50
# ...

# %% [markdown]
# #### Pleae note below that we never learned seaborn or how to generate a heatmap so I had to ask Dot! The code below is what was provided to me

# %%
# Create a heatmap of platform sales over time
# Create the pivot table
heatmap_data = plat_year.reset_index().pivot(index='platform', 
                                           columns='year_of_release', 
                                           values='total_sales')

# Make it much more readable
plt.figure(figsize=(16, 10))  # Bigger size
sns.heatmap(heatmap_data, 
            annot=False,        # Remove the numbers - they're cluttering!
            cmap='Reds',        # Simpler color scheme
            cbar_kws={'label': 'Total Sales (millions)'})

plt.title('Platform Sales Over Time (Heatmap)', fontsize=16, pad=20)
plt.xlabel('Year of Release', fontsize=12)
plt.ylabel('Platform', fontsize=12)
plt.xticks(rotation=45)  # Rotate year labels
plt.yticks(rotation=0)   # Keep platform names horizontal
plt.tight_layout()       # Better spacing
plt.show()

# %% [markdown]
# ##### year 2016 looks like a tough year (even though it's not completed). There isn't any 'red hot items' when looking at the heatmap from above. Looks like the only popular sales in 2016 is PS4 platform. 2015 wasn't also all that hot either. Their hottest item was only PS4. Xbox One looks like they didn't so well compared to PS4.

# %%
# Identify platforms with declining sales
# identifying platforms by seeing if the total sales are greater than 0 total sales in 2016
current_platforms = games[games['year_of_release'] == 2016]
display(current_platforms)
# Out:
#                                  name platform  year_of_release         genre  \
# 94                            FIFA 17      PS4             2016        Sports
# 108                  Pokemon Sun/Moon      3DS             2016  Role-Playing
# 171        Uncharted 4: A Thief's End      PS4             2016       Shooter
# 245    Call of Duty: Infinite Warfare      PS4             2016       Shooter
# 289                     Battlefield 1      PS4             2016       Shooter
# ...                               ...      ...              ...           ...
# 16699           The Longest 5 Minutes      PSV             2016        Action
# 16703                Strawberry Nauts      PSV             2016     Adventure
# 16710   Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16712         Haitaka no Psychedelica      PSV             2016     Adventure
# 16714             Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# ### We see there's barely any sales for PSV and PS3. Looks like PS4 has active sales due to FIFA, COD, Battlefield, etc. I see 3DS is still making sales for pokemon games. I wonder if became popular due to Pokemon go?

# %%
# let's sort by the total sales descending to get a better picture
display(current_platforms.sort_values('total_sales',ascending=False))
# Out:
#                                   name platform  year_of_release  \
# 94                             FIFA 17      PS4             2016
# 108                   Pokemon Sun/Moon      3DS             2016
# 171         Uncharted 4: A Thief's End      PS4             2016
# 245     Call of Duty: Infinite Warfare      PS4             2016
# 289                      Battlefield 1      PS4             2016
# ...                                ...      ...              ...
# 16264                       Worms: WMD     XOne             2016
# 16238                Fernbus Simulator       PC             2016
# 16201                 The Technomancer       PC             2016
# 16188  Darksiders: Warmastered Edition     XOne             2016
# 16714              Winning Post 8 2016      PSV             2016
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 94           Sports      0.66      5.75      0.08         1.11          85.0
# ...

# %%
# Seeing the list of platforms
print(current_platforms['platform'].value_counts())
# Out:
# PS4     164
# XOne     87
# PSV      85
# PC       54
# 3DS      46
# PS3      38
# WiiU     14
# X360     13
# Wii       1
# Name: platform, dtype: int64

# %% [markdown]
# ##### We see that PS4 has been on the list 164 times from the current_platform and there's still some games for 3DS. It's time to go by sales per platform.

# %%
# calculate sales by platform for 2016
current_platform_sales = current_platforms.groupby('platform')['na_sales','eu_sales','jp_sales','other_sales','total_sales'].sum()

display(current_platform_sales.sort_values('total_sales',ascending=False))
# Out:
#           na_sales  eu_sales  jp_sales  other_sales  total_sales
# platform
# PS4          21.49     31.78      5.74        10.24        69.25
# XOne         14.27      9.63      0.01         2.24        26.15
# 3DS           4.14      2.33      8.03         0.64        15.14
# PC            1.36      3.53      0.00         0.36         5.25
# WiiU          2.10      1.48      0.67         0.35         4.60
# PSV           0.15      0.39      3.56         0.15         4.25
# PS3           0.67      1.26      1.30         0.37         3.60
# X360          0.69      0.71      0.00         0.12         1.52
# Wii           0.06      0.11      0.00         0.01         0.18

# %% [markdown]
# ##### For 2016, we can see that PS4 has the highest sales for 164 games, that averages about 0.42 million per game. Xbox One is still solid despite being less than half of PS4 Sales. 3DS has some sales which is quite impressive for a handheld platform for 46 games; an average of of .33 million a game. I also noticed by region, jp_sales is almost twice the amount as na_sales.

# %%
# calculate the average sales for 2016 by platform
current_platform_sales_avg = current_platforms.groupby('platform')['na_sales','eu_sales','jp_sales','other_sales','total_sales'].agg(['sum','mean','std','count'])
display(current_platform_sales_avg)
# Out:
#          na_sales                           eu_sales                      \
#               sum      mean       std count      sum      mean       std
# platform
# 3DS          4.14  0.090000  0.438756    46     2.33  0.050652  0.215926
# PC           1.36  0.025185  0.051970    54     3.53  0.065370  0.090631
# PS3          0.67  0.017632  0.033323    38     1.26  0.033158  0.090944
# PS4         21.49  0.131037  0.297298   164    31.78  0.193780  0.571712
# PSV          0.15  0.001765  0.006395    85     0.39  0.004588  0.013763
# Wii          0.06  0.060000       NaN     1     0.11  0.110000       NaN
# WiiU         2.10  0.150000  0.181490    14     1.48  0.105714  0.090018
# X360         0.69  0.053077  0.054831    13     0.71  0.054615  0.072528
# XOne        14.27  0.164023  0.300401    87     9.63  0.110690  0.264037
#
#                jp_sales                           other_sales            \
#          count      sum      mean       std count         sum      mean
# ...

# %% [markdown]
# #### PS4's sales is the highest in 2016 with it's standard deviation being 0.97. Even though XOne has 62.24% less sales than PS4 with an average sales of 0.30M per game, their standard deviation for 2016 sales is more consistant than PS$. 3DS total sales is 15.14 with only 46 games (average about 0.33M per game), with a relatively consistent performance with a standard deviation of 1.06
#
# #### Another thing I noticed for 2016 sales is that 7 out of 9 platforms, eu_sales is higher than na_sales which is quite interesting considering North America has the largest gaming market globally.

# %%
# identify the platforms that are no longer in the market
# let's start with getting the list of all platforms
all_platforms = games['platform'].unique()

# find platforms active in 2016
platforms_2016 = games[games['year_of_release'] == 2016]['platform'].unique()

# identify the disappeared platforms
disappeared_platforms = set(all_platforms) - set(platforms_2016)
print(sorted(disappeared_platforms))
# Out:
# ['2600', '3DO', 'DC', 'DS', 'GB', 'GBA', 'GC', 'GEN', 'GG', 'N64', 'NES', 'NG', 'PCFX', 'PS', 'PS2', 'PSP', 'SAT', 'SCD', 'SNES', 'TG16', 'WS', 'XB']

# %%
# Calculate the lifecycle of a gaming platform
# Let's group platform by year_of_release
platform_year_cycle = games[games['year_of_release'] > 0].groupby('platform')['year_of_release'].agg(['min','max'])

#calculate the lifespan of each console
platform_year_cycle['life_cycle'] = platform_year_cycle['max'] - platform_year_cycle['min']

display(platform_year_cycle.sort_values('life_cycle',ascending=False))
# Out:
#            min   max  life_cycle
# platform
# PC        1985  2016          31
# DS        1985  2013          28
# GB        1988  2001          13
# X360      2005  2016          11
# PSP       2004  2015          11
# PS2       2000  2011          11
# NES       1983  1994          11
# DC        1998  2008          10
# Wii       2006  2016          10
# PS3       2006  2016          10
# 2600      1980  1989           9
# SNES      1990  1999           9
# PS        1994  2003           9
# XB        2000  2008           8
# GBA       2000  2007           7
# GC        2001  2007           6
# N64       1996  2002           6
# 3DS       2011  2016           5
# PSV       2011  2016           5
# SAT       1994  1999           5
# WiiU      2012  2016           4
# GEN       1990  1994           4
# NG        1993  1996           3
# XOne      2013  2016           3
# PS4       2013  2016           3
# WS        1999  2001           2
# 3DO       1994  1995           1
# ...

# %% [markdown]
# #### We see that Nintendo DS has a min year for 1985 which is incorrect. Nintendo DS wasn't realeased until 2004. When filtering to 3DS for 1985 year_of_release, we see there's only one game, which is "Strongest Tokyo University Shogi DS". We know that the DS wasn't invented in 1985. It could be an original game reference where the DS version was based on a 1985 original and the data got mixed up. We will need to change the 1985 date to 2007 since we know the year_of_release is incorrect.

# %%
# change the year_of_release to 2007
games.loc[15957,'year_of_release'] = 2007 # I located the row by using csv sheet
print(games.loc[15957])
# Out:
# name               Strongest Tokyo University Shogi DS
# platform                                            DS
# year_of_release                                   2007
# genre                                           Action
# na_sales                                           0.0
# eu_sales                                           0.0
# jp_sales                                          0.02
# other_sales                                        0.0
# critic_score                                       NaN
# user_score                                         NaN
# rating                                             NaN
# total_sales                                       0.02
# Name: 15957, dtype: object

# %%
# Recalculate platform lifecycles with the corrected data
platform_year_cycle = games[games['year_of_release'] > 0].groupby('platform')['year_of_release'].agg(['min','max'])
platform_year_cycle['life_cycle'] = platform_year_cycle['max'] - platform_year_cycle['min']
display(platform_year_cycle.sort_values('life_cycle', ascending=False))
# Out:
#            min   max  life_cycle
# platform
# PC        1985  2016          31
# GB        1988  2001          13
# NES       1983  1994          11
# X360      2005  2016          11
# PSP       2004  2015          11
# PS2       2000  2011          11
# DC        1998  2008          10
# Wii       2006  2016          10
# PS3       2006  2016          10
# 2600      1980  1989           9
# SNES      1990  1999           9
# PS        1994  2003           9
# DS        2004  2013           9
# XB        2000  2008           8
# GBA       2000  2007           7
# GC        2001  2007           6
# N64       1996  2002           6
# SAT       1994  1999           5
# 3DS       2011  2016           5
# PSV       2011  2016           5
# WiiU      2012  2016           4
# GEN       1990  1994           4
# NG        1993  1996           3
# PS4       2013  2016           3
# XOne      2013  2016           3
# WS        1999  2001           2
# SCD       1993  1994           1
# ...

# %% [markdown]
# ##### Perfect!!! Now we see the accurate life cycle of Nintendo DS from 2004 to 2009

# %%
# calculate the mean of the lifecycle
print(f"the average life cycle of a platform is {platform_year_cycle['life_cycle'].mean().round(2)}")
# Out:
# the average life cycle of a platform is 7.0

# %% [markdown]
# <div style="border: 5px solid green; padding: 10px; margin: 5px">
# <b> Reviewer's comment </b>
#
# Yes, the average lifetime is about 10 years.
#
# </div>

# %% [markdown]
# ### Questions to Consider:
# - Which platforms show consistent sales over time?
#     - PS and PS2 showed consistent sales over time before they were no longer in the market. PS3 was consistent but by looking at the heatmap, they didn't get to $200 million in sales like the previous consoles. As for PS4, even though it's relatively new, they had a decreased sale in 2016 from their previous year in 2015. The console that showed consistent sales overtime during their time were: X360, Wii, and DS
# - Can you identify platforms that have disappeared from the market?
#     - Yes, by looking at cell [72], we have the following platforms that are no longer in the market: ['2600', '3DO', 'DC', 'DS', 'GB', 'GBA', 'GC', 'GEN', 'GG', 'N64', 'NES', 'NG', 'PCFX', 'PS', 'PS2', 'PSP', 'SAT', 'SCD', 'SNES', 'TG16', 'WS', 'XB']
# - What's the typical lifecycle of a gaming platform?
#     - While PS4 and Xbox one are still going active in 2016 sales and still counting, it seems like the average life is 7 years. While it's no surprised that PC games are still active since 1985 regardless the lack of sales in PC game purchased from our store, it's impressive how PS 1-3, Xbox 360, NES, and GB lasted over double digits. They don't make consoles that long as they used to.

# %% [markdown]
# ## 3.3 Determining Relevant Time Period
#
# Based on your analysis above, determine the appropriate time period for predicting 2017 sales:

# %%
# Your code here to filter the dataset to relevant years
# Example:
# relevant_years = [XXXX, XXXX, XXXX] # Replace with your chosen years
# df_relevant = df[df['year_of_release'].isin(relevant_years)]
relevant_years = [2013,2014,2015,2016]
df_relevant = games[games['year_of_release'].isin(relevant_years)]
display(df_relevant.sort_values('total_sales',ascending=False))

# Justify your choice with data
# Out:
#                                 name platform  year_of_release         genre  \
# 16                Grand Theft Auto V      PS3             2013        Action
# 23                Grand Theft Auto V     X360             2013        Action
# 31         Call of Duty: Black Ops 3      PS4             2015       Shooter
# 33               Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# 42                Grand Theft Auto V      PS4             2014        Action
# ...                              ...      ...              ...           ...
# 16264                     Worms: WMD     XOne             2016        Action
# 16267  The Book of Unwritten Tales 2     WiiU             2016     Adventure
# 16270                   Hyakka Yakou      PSV             2015        Action
# 16273             Doki-Doki Universe      PSV             2013     Adventure
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# <div style="border: 5px solid blue; padding: 15px; margin: 5px">
#
# <b> Document Your Decision:</b>
# ~~- What years did you select and why?
#     - I pick 2011 to 2015 and not going to include 2016 sales since the instructions mentioned Data for 2016 may be incomplete. My concerns for 2016 sales are:
#         - Collection cuttoff: Data might be incomplete due to new games being late in the year may not have full sales yet. For instance: I know that Assassin's Creed is a popular game but when I filtered to Assassins's on the csv sheet (Assassin's Creed Chronicles and Assassin's Creed: The Ezio Collection), for 2016 release, for PS4, PSV, and Xbox One consoles, it only genreated $0.44M in sales which I know it's inaccurate
#     - 2016 games might still have TBD ratings
#     - Recent games might not have complete critic/user scores yet.~~
# - <span style="background-color:#e6f2ff"> **Correction: The years we're going to select are 2013 to 2016. I originally said 2011 to 2015 but 2011 is during their highest sales peak and after 2012, sales were declining. If we picked 2011 for our 2017 campgin, it would skewed our data.**
# - How does this period reflect current market conditions?
#     - it reflects the active platforms that's still generating sales. We know that a console last about 7 years on average and it takes about 3 years to reach it's peak. ~~The top 3 platforms are PS4, Xone, and 3DS~~. ~~3DS was released in 2011.~~<span style="background-color:#e6f2ff"> **Correction: The top 3 platforms from the time frame are: PS4, PS3, and Xbox One. 3DS is in 4th place where JP Region is almost doubled the amount in sales compared to NA and EU sales.**
# - What factors influenced your decision?
#     - Based on the history of each platform's lifespan, their sales based on the heatmap, and which platoform is currently active. ~~Knowing that 2016 sales is not fully complete, I don't think it would help with our hypothesis testing~~
#
# </div>

# %% [markdown]
# <div style="border: 5px solid green; padding: 10px; margin: 5px">
# <b> Reviewer's comment 2</b>
#
# It's a good choice for the following three reasons:
#
#
#
# 1. Years before 2012 have huge sales volume, which can influence our distributions.
#
#
# 2. New platforms appeared in 2012-2013, which means that these huge sales were generated by older platforms that cannot be relevant for so many years.
#
# 3. Since graphics and other components change fast, users' preferences change as well. It means that most people had different perceptions 10 years ago compared to their current perception.
#
#
#
#
# </div>

# %% [markdown]
# <div style="border: 5px solid red; padding: 10px; margin: 5px">
# <b> Reviewer's comment</b>
#
# - We should not drop 2016. It's ok that we have incomplete data, as business may make predictions in October/November, not in late December
#
#
# - Let's adjust this choice and take years from 2012 or 2013. Years before 2012 have huge sales volume, which can influence our distributions. Moreover, new platforms appeared in 2012-2013, which means that these huge sales were generated by older platforms that cannot be relevant for so many years.
#
# </div>

# %% [markdown]
# ## 3.4 Platform Performance Analysis
#
# Using your selected time period, let's analyze platform performance:

# %%
# Analyze platform sales trends
df_relevant_plat = df_relevant.groupby('platform')['na_sales','eu_sales','jp_sales','other_sales','total_sales'].sum()
display(df_relevant_plat)
# Out:
#           na_sales  eu_sales  jp_sales  other_sales  total_sales
# platform
# 3DS          38.20     30.96     67.81         6.28       143.25
# DS            0.57      0.85      0.00         0.12         1.54
# PC           11.11     25.36      0.00         2.96        39.43
# PS3          63.50     67.81     23.35        26.77       181.43
# PS4         108.74    141.09     15.96        48.35       314.14
# PSP           0.00      0.17      3.29         0.04         3.50
# PSV           5.04      6.10     18.59         3.26        32.99
# Wii           6.56      5.93      0.05         1.12        13.66
# WiiU         29.21     19.85     10.88         4.69        64.63
# X360         81.66     42.52      0.51        12.11       136.80
# XOne         93.12     51.59      0.34        14.27       159.32

# %%
# Sort platforms by total sales
display(df_relevant_plat.sort_values('total_sales',ascending=False))
# Out:
#           na_sales  eu_sales  jp_sales  other_sales  total_sales
# platform
# PS4         108.74    141.09     15.96        48.35       314.14
# PS3          63.50     67.81     23.35        26.77       181.43
# XOne         93.12     51.59      0.34        14.27       159.32
# 3DS          38.20     30.96     67.81         6.28       143.25
# X360         81.66     42.52      0.51        12.11       136.80
# WiiU         29.21     19.85     10.88         4.69        64.63
# PC           11.11     25.36      0.00         2.96        39.43
# PSV           5.04      6.10     18.59         3.26        32.99
# Wii           6.56      5.93      0.05         1.12        13.66
# PSP           0.00      0.17      3.29         0.04         3.50
# DS            0.57      0.85      0.00         0.12         1.54

# %% [markdown]
# <div style="border: 5px solid blue; padding: 15px; margin: 5px">
# <del>~~We see that PS3 is the top performaner from 2011-2015 which makes sense since PS4 and XOne wasn't released till 2013 so this explains why PS3 would be the top performaner from 2011-2015!~~</del>
#
# <span style="background-color:#e6f2ff">**Correction: We see that PS4 is the highest platform from 2013-2016 which makes sense since PS4 was released in 2013 and it's going strong. Since PS4 is made, that means PS3 console games are declining but they're still in second place from the interval years**

# %% [markdown]
# <div style="border: 5px solid green; padding: 10px; margin: 5px">
# <b> Reviewer's comment 2</b>
#
# Good!
#
# </div>

# %%
# Visualize top platforms
# Calculate year-over-year growth for each platform
# Your code here to calculate and visualize platform growth rates
platform_year_growth = df_relevant.groupby(['platform','year_of_release'])['na_sales','eu_sales','jp_sales','other_sales','total_sales'].sum()
platform_year_growth['pct_change%'] = platform_year_growth.groupby('platform')['total_sales'].pct_change() # DOT explained the pct_change function
platform_year_growth['pct_change%'] = (platform_year_growth['pct_change%'] * 100).round(2)
display(platform_year_growth)
# Out:
#                           na_sales  eu_sales  jp_sales  other_sales  \
# platform year_of_release
# 3DS      2013                15.56     14.84     23.57         2.60
#          2014                12.33      8.73     20.69         2.01
#          2015                 6.17      5.06     15.52         1.03
#          2016                 4.14      2.33      8.03         0.64
# DS       2013                 0.57      0.85      0.00         0.12
# PC       2013                 3.88      7.39      0.00         1.11
#          2014                 3.51      8.87      0.00         0.90
#          2015                 2.36      5.57      0.00         0.59
#          2016                 1.36      3.53      0.00         0.36
# PS3      2013                41.45     42.27     12.13        17.40
#          2014                16.39     18.24      6.25         6.88
#          2015                 4.99      6.04      3.67         2.12
# ...

# %% [markdown]
# <div style="border: 5px solid blue; padding: 15px; margin: 5px">
#
# <b> We see a lot of platforms are declining except for Xone and PS4 which were popular consoles in 2015. Looking at 3DS even by jp_sales region, the sales are declining but have stronger sales than eu_sales and na_sales. <b>
#
# <span style="background-color:#e6f2ff"> **Additional Comment: We see that Xone and PS4 had a tremoundous sales in 2014 after being released in 2013.**
# - <span style="background-color:#e6f2ff"> **For instance, XOne had a 185.18% sales increase overall in 2014 then had a 11.23% increase in 2015.**
# - <span style="background-color:#e6f2ff"> **PS4 had a whopping 284.76% sales increase in 2014 then 18.90% increase in sales in 2015**

# %% [markdown]
# <div style="border: 5px solid green; padding: 10px; margin: 5px">
# <b> Reviewer's comment 2</b>
#
# Agreed.
# </div>

# %% [markdown]
# ## 3.5 Sales Distribution Analysis
#
# Let's examine the distribution of sales across platforms:

# %%
# Filter to the active platoforms in 2015
active_2015 = df_relevant[df_relevant['year_of_release'].isin([2014,2015])]
active_plat_2015 = active_2015['platform'].unique()
print(f"The current active platforms in 2014 and 2015 are: {active_plat_2015}")
print()
# Create box plot of sales by platform
sns.boxplot(x='platform', y='total_sales', data = active_2015)
plt.show()
# Out:
# The current active platforms in 2014 and 2015 are: ['PS4' '3DS' 'XOne' 'WiiU' 'PS3' 'X360' 'PC' 'Wii' 'PSV' 'PSP']

# %% [markdown]
# ##### We see that PS4 and XOne are the best platform for 2014-2015 with a lot of outliers on the box plot. The median sales are the same

# %%
# Calculate detailed statistics for each platform
df_releveant_stats = df_relevant.groupby('platform')['na_sales','eu_sales','jp_sales','other_sales','total_sales'].agg(['sum','mean','std']).round(2)
display(df_releveant_stats.sort_values(('total_sales','sum'),ascending=False))
# Out:
#          na_sales             eu_sales             jp_sales              \
#               sum  mean   std      sum  mean   std      sum  mean   std
# platform
# PS4        108.74  0.28  0.58   141.09  0.36  0.81    15.96  0.04  0.07
# PS3         63.50  0.18  0.52    67.81  0.20  0.66    23.35  0.07  0.11
# XOne        93.12  0.38  0.63    51.59  0.21  0.37     0.34  0.00  0.01
# 3DS         38.20  0.13  0.50    30.96  0.10  0.38    67.81  0.22  0.57
# X360        81.66  0.44  1.02    42.52  0.23  0.54     0.51  0.00  0.01
# WiiU        29.21  0.25  0.47    19.85  0.17  0.30    10.88  0.09  0.24
# PC          11.11  0.06  0.13    25.36  0.13  0.21     0.00  0.00  0.00
# PSV          5.04  0.01  0.04     6.10  0.02  0.06    18.59  0.05  0.08
# Wii          6.56  0.29  0.51     5.93  0.26  0.35     0.05  0.00  0.01
# PSP          0.00  0.00  0.00     0.17  0.00  0.02     3.29  0.05  0.06
# DS           0.57  0.07  0.10     0.85  0.11  0.08     0.00  0.00  0.00
#
# ...

# %% [markdown]
# <div style="border: 5px solid blue; padding: 10px; margin: 5px">
#
# <del>PS3 is the highest sales since we picked the years 2011-2015. Please note that PS4 wasn't released until 2013. We also noticed that PC games; eu_sales almost doubled the sales compared to na_sales and jp_sales is flat 0. So I guess that means Japan is not big on PC games. They're more into handheld platforms like the Nintendo 3DS where it was more sales than na_sales.</del>
#
# <del>
# ##### Despite the fact that PS3 has the highest sales, their average sales per game is 0.66 M per game. PS4 has the highest average of $1.07M with std 1.90 per game while Xbox One is in second with 0.83M per game with std of 1.18. PS4 with a std of 1.9 shows that is has a high variability which can have a strong market appeal. I think 2017 will be a good year for PS4 and Xbox One.
# </del>
#
# <div style="background-color:#e6f2ff; padding: 10px;">
# <b>Correction:</b> I know the comment says it's good, but with the new relevant years selected, <b>PS3 is no longer the highest in total sales.</b> For our updated period (2013–2016), <b>PS4 leads by a long shot</b>. I'm a little surprised to see Xbox One in third, with PS3 still holding second despite being closer to the end of its lifecycle.
#
# <ul>
#   <li><b>PS4</b> has an average sales/game of <b>0.80M</b> with a std dev of <b>1.61</b>, indicating high variability and strong market appeal.</li>
#   <li><b>Xbox One</b> is second in average sales/game with <b>0.65M</b> and a std dev of <b>1.04</b>.</li>
#   <li><b>While PS3</b> still has the second-highest total sales, its average sales/game is lower at <b>0.53M</b>, showing it's fading out.</li>
#   <li><b>PC games</b> sell best in North America (<b>11.11M</b>), but have very low performance in other regions. It suggests PC gaming is less relevant globally during this time.</li>
#   <li><b>Nintendo 3DS</b> is Japan's top seller, but the average sales/game is only <b>0.22M</b> with a std of <b>0.57</b>, showing limited blockbuster potential.</li>
# </ul>
# </div>
# </div>

# %% [markdown]
# <div style="border: 5px solid green; padding: 10px; margin: 5px">
# <b> Reviewer's comment </b>
#
#
# Well done!
# </div>

# %% [markdown]
# <div style="border: 5px solid green; padding: 10px; margin: 5px">
# <b> Reviewer's comment 2 </b>
#
#
# Makes sense. So a boxplot shows us a distribution, like a histogram. 2 pictures below represent it:
#
#
# ![image info](https://r-charts.com/en/distribution/histogram-boxplot_files/figure-html/histogram-boxplot.png)
#
#
# ![image.png](https://i.ytimg.com/vi/FPREzlHdWRY/maxresdefault.jpg)
#
#
#
# But the boxplot is better, since we don't have to think about `bins` parameter for a histogram. Boxplot also shows us some statistics, while histogram doesn't.
#
#
# What does our boxplot tell us about? Since we are plotting sum world sales per game, outliers are just some very popular games. I would even say bestsellers. And this is a very illustrative thing. Look at the 3DS. Small box and lots of outliers. This suggests that a large part of the sales volume comes from these outliers. At the same time, the XOne has a different situation: a large box, a long whisker and few outliers. This indicates that a wide variety of games are bought on XOne, and, moreover, in considerable quantities.
#
#  </div>

# %% [markdown]
# ## 3.6 Review Score Impact Analysis
#
# Select a popular platform and analyze how reviews affect sales:

# %%
# Choose a popular platform based on your previous analysis
ps4 = df_relevant[df_relevant['platform'] == 'PS4']
display(ps4.sort_values('total_sales',ascending=False))
# Out:
#                                     name platform  year_of_release  \
# 31             Call of Duty: Black Ops 3      PS4             2015
# 42                    Grand Theft Auto V      PS4             2014
# 77                               FIFA 16      PS4             2015
# 87          Star Wars Battlefront (2015)      PS4             2015
# 92        Call of Duty: Advanced Warfare      PS4             2014
# ...                                  ...      ...              ...
# 15943           Professional Farmer 2016      PS4             2015
# 15864  Rocksmith 2014 Edition Remastered      PS4             2016
# 15839         Mark McMorris Infinite Air      PS4             2016
# 15790                   This War of Mine      PS4             2016
# 16585      Farming 2017 - The Simulation      PS4             2016
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 31        Shooter      6.03      5.86      0.36         2.38           NaN
# ...

# %% [markdown]
# ##### The reason I picked PS4 because it's the all time best sales across all regions during the relevant years

# %%
# Plot a scatter plot for user_score and critic_score
# Replace 'tbd' with NaN and convert to numeric
ps4_clean = ps4.copy()  # Make a copy so we don't mess up the original
ps4_clean['user_score'] = pd.to_numeric(ps4_clean['user_score'], errors='coerce')

# Remove rows where any of our plotting columns have NaN
columns_to_plot = ['critic_score','user_score','total_sales']
ps4_clean = ps4_clean[columns_to_plot].dropna()

# Create the scatter matrix (note: no square brackets around columns_to_plot)
pd.plotting.scatter_matrix(ps4_clean)
plt.show()
print()
print(ps4_clean['user_score'].dtype)
# Out:
# float64

# %% [markdown]
# ##### There's a clear strong relationship between user_score and critic_score: When critic_score increases, user_score also increases as well.
#
# ##### The relationships between the scores vs sales is interesting. It appears to be a weak negative or no clear relationship between the scores and sales. It could be possible that the user_score or critic_score only has one reviewer for a certain game that has a very low sale. Another factor is that one harsh review could skew the rating. Since we're not sure of the sample sizes of the critic and user reviews, there's many possibilities on why the scores and total_sales doesn't have a strong relationship as we expected.  It looks like the sales are closer to 0 but there are a few that are right-skewed; they must be blockbuster hits with very high sales numbers.

# %%
# Critic Scores
corr_critic = ps4_clean['critic_score']

# User Scores
corr_user = ps4_clean['user_score']

# Calculate correlations
print(f"the correlation relationship between critic_sore and user_score is: {corr_critic.corr(corr_user)}")
# Out:
# the correlation relationship between critic_sore and user_score is: 0.5576539782764632

# %% [markdown]
# ##### the correlation relationship between critic and user reviewers is moderate. Looking over at the scatterplot again, I notice the points form more of a 'cloud' rather than a tight line. Despite the fact, they're an upward trend, there's quite a bit of scatter around the trend line. Again, it's possible there were some harsh reviewers that skewed the score's average.

# %% [markdown]
# ## 3.7 Cross-Platform Comparison
#
# Compare sales performance of games across different platforms:

# %%
# Find games released on multiple platforms
display(df_relevant['name'].value_counts())
name_counts = df_relevant['name'].value_counts()
# filter to names that has more than one platform
multi_game_names = name_counts[name_counts > 1].index
# filter the original df to include on those multi-platform games
multi_games = df_relevant[df_relevant['name'].isin(multi_game_names)]

display(multi_games)
# Out:
# LEGO Marvel Super Heroes                         9
# FIFA 14                                          9
# LEGO Jurassic World                              8
# LEGO The Hobbit                                  8
# Angry Birds Star Wars                            8
#                                                 ..
# PriPara Mezameyo! Megami no Dress Design         1
# Urakata Hakuoki                                  1
# Himoutou! Umaru-Chan: Himoutou Ikusei Keikaku    1
# Geten no Hana: Yume Akari                        1
# Diabolik Lovers: Vandead Carnival                1
# Name: name, Length: 1263, dtype: int64
#                                                 name platform  \
# 16                                Grand Theft Auto V      PS3
# 23                                Grand Theft Auto V     X360
# 31                         Call of Duty: Black Ops 3      PS4
# 42                                Grand Theft Auto V      PS4
# ...

# %% [markdown]
# <div style="border: 5px solid blue; padding: 10px; margin: 5px">
# <del>I'm not shocked to see Madden NFL 07 and FIFA 14 to have multi-platform as they are popular sports across the country and region. What I'm shocked to see is Rataouille being across the multi-platform. Granted it was a great movie, but I didn't know it had a video game. </del>
#
# <span style="background-color:#e6f2ff"> **LEGO games seem to be a popular game during this time frame. It's no surprised to see FIFA being in most of multi-platforms. It is clear that GTA V and COD games were in the top sales in multiple platforms**

# %%
# Compare sales across platforms for these games
multi_sales = multi_games.groupby('platform')['na_sales','eu_sales','jp_sales','other_sales','total_sales'].sum()
# Your code here to analyze and visualize cross-platform performance
display(multi_sales.sort_values('total_sales',ascending=False))
# Out:
#           na_sales  eu_sales  jp_sales  other_sales  total_sales
# platform
# PS4          96.44    126.28     13.61        43.12       279.45
# PS3          58.07     63.40     18.38        24.86       164.71
# XOne         78.55     44.25      0.19        12.10       135.09
# X360         80.25     41.86      0.45        11.92       134.48
# PC            7.76     17.36      0.00         1.95        27.07
# WiiU         11.21      7.46      2.04         1.78        22.49
# 3DS           8.11      6.73      4.30         1.35        20.49
# PSV           2.67      4.18     10.04         1.96        18.85
# Wii           6.56      5.93      0.00         1.12        13.61
# DS            0.57      0.85      0.00         0.12         1.54
# PSP           0.00      0.17      1.23         0.04         1.44

# %% [markdown]
# <div style="border: 5px solid blue; padding: 10px; margin: 5px">
# <del> We see that PS2 was the all time highest sales in multi_game platform even after being out of the market in 2012. Looking at the table, NA_sales are dominating on most of the platforms. The worst platform that only sold in Japan was WS and NG platforms. PS4 has higher sales in Europe over NA region but the sales in 2016 are incomplete so we're not sure if it's true yet.</del>
#
# <span style="background-color:#e6f2ff"> <b> We see PS4 is the best platform during the years of 2013-2016. Looking at the table, NA_sales are lead the sales for some platforms. EU_Sales are lead in PS4 and PS3 games. Also am shocked to see that na_sales and eu_sales are leading in JP for Nintendo 3DS. I thought they would dominate sales in that platform from our previous results from above!</b>
# </div>

# %% [markdown]
# <div style="border: 5px solid green; padding: 10px; margin: 5px">
# <b> Reviewer's comment 2 </b>
#
# True. </div>

# %% [markdown]
# ## 3.8 Genre Analysis
#
# Finally, let's examine the distribution of games by genre:

# %%
# Analyze genre performance
genre_sales = df_relevant.groupby('genre')['na_sales','eu_sales','jp_sales','other_sales','total_sales'].sum()
display(genre_sales)
# Out:
#               na_sales  eu_sales  jp_sales  other_sales  total_sales
# genre
# Action          126.05    118.13     40.49        37.20       321.87
# Adventure         7.14      8.25      5.82         2.43        23.64
# Fighting         15.55      8.55      7.65         3.56        35.31
# Misc             27.49     20.04      9.20         6.09        62.82
# Platform         18.14     15.58      4.79         4.12        42.63
# Puzzle            0.83      1.00      1.18         0.16         3.17
# Racing           12.96     20.19      2.30         4.44        39.89
# Role-Playing     46.40     36.97     51.04        11.48       145.89
# Shooter         109.74     87.86      6.61        28.77       232.98
# Simulation        4.86     10.92      4.52         1.46        21.76
# Sports           65.27     60.52      5.41        19.45       150.65
# Strategy          3.28      4.22      1.77         0.81        10.08

# %% [markdown]
# <div style="border: 5px solid red; padding: 10px; margin: 5px">
# <b> Reviewer's comment </b>
#
#
# Here and further, we have to use relevant time interval. </div>

# %% [markdown]
# <div style="border: 5px solid blue; padding: 10px; margin: 5px">
# Thank you for catching my error by accidentally going back to games df over df_relevant. I should had caught that before submitting! 😬

# %% [markdown]
# <div style="border: 5px solid green; padding: 10px; margin: 5px">
# <b> Reviewer's comment 2 </b>
#
# True.
#
# </div>

# %%
# Sort genres by total sales
display(genre_sales.sort_values('total_sales',ascending=False))
# Out:
#               na_sales  eu_sales  jp_sales  other_sales  total_sales
# genre
# Action          126.05    118.13     40.49        37.20       321.87
# Shooter         109.74     87.86      6.61        28.77       232.98
# Sports           65.27     60.52      5.41        19.45       150.65
# Role-Playing     46.40     36.97     51.04        11.48       145.89
# Misc             27.49     20.04      9.20         6.09        62.82
# Platform         18.14     15.58      4.79         4.12        42.63
# Racing           12.96     20.19      2.30         4.44        39.89
# Fighting         15.55      8.55      7.65         3.56        35.31
# Adventure         7.14      8.25      5.82         2.43        23.64
# Simulation        4.86     10.92      4.52         1.46        21.76
# Strategy          3.28      4.22      1.77         0.81        10.08
# Puzzle            0.83      1.00      1.18         0.16         3.17

# %% [markdown]
# <div style="border: 5px solid blue; padding: 10px; margin: 5px">
# <b>Action, Sports, and Shooting are the top 3 Genres. While Strategy did a decent job of making <del>174.23M</del> <span style="background-color:#e6f2ff"> 10.08M</span> in sales; it was the lowest of sales (technically it's 'unk' but since we don't know which genre it belongs, we had to name it as unknown).</b>

# %%
# Visualize genre distribution
# get the number of games per genre
genre_games = df_relevant.groupby('genre')['name'].agg('count')
display(genre_games)
# Out:
# genre
# Action          766
# Adventure       245
# Fighting         80
# Misc            155
# Platform         74
# Puzzle           17
# Racing           85
# Role-Playing    292
# Shooter         187
# Simulation       62
# Sports          214
# Strategy         56
# Name: name, dtype: int64

# %%
# Create a horizontal bar graph

plt.barh(genre_games.index, genre_games.values, color='skyblue')
plt.title('Number of games per Genre')
plt.xlabel('# of distributions')
plt.ylabel('Genre')
plt.show()

# %% [markdown]
# <div style="border: 5px solid blue; padding: 10px; margin: 5px">
# <b>We see that Action and </b><del>Sports</del> <b><span style="background-color:#e6f2ff"> Role-Playing</span> are the highest releases throughout the years</b>

# %%
# Calculate market share for each genre
genre_sales_avg = df_relevant.groupby('genre').agg({
    'name': 'count',  # Count the games
    'na_sales': ['mean', 'sum'],  # Average and total NA sales
    'eu_sales': ['mean', 'sum'],  # Average and total EU sales
    'jp_sales': ['mean', 'sum'],  # Average and total JP sales
    'other_sales': ['mean', 'sum'],  # Average and total other sales
    'total_sales': ['mean', 'sum']   # Average and total sales
})
display(genre_sales_avg.sort_values(('total_sales','sum'),ascending=False))
# Out:
#               name  na_sales          eu_sales          jp_sales         \
#              count      mean     sum      mean     sum      mean    sum
# genre
# Action         766  0.164556  126.05  0.154217  118.13  0.052859  40.49
# Shooter        187  0.586845  109.74  0.469840   87.86  0.035348   6.61
# Sports         214  0.305000   65.27  0.282804   60.52  0.025280   5.41
# Role-Playing   292  0.158904   46.40  0.126610   36.97  0.174795  51.04
# Misc           155  0.177355   27.49  0.129290   20.04  0.059355   9.20
# Platform        74  0.245135   18.14  0.210541   15.58  0.064730   4.79
# Racing          85  0.152471   12.96  0.237529   20.19  0.027059   2.30
# Fighting        80  0.194375   15.55  0.106875    8.55  0.095625   7.65
# Adventure      245  0.029143    7.14  0.033673    8.25  0.023755   5.82
# Simulation      62  0.078387    4.86  0.176129   10.92  0.072903   4.52
# Strategy        56  0.058571    3.28  0.075357    4.22  0.031607   1.77
# ...

# %% [markdown]
# <div style="border: 5px solid blue; padding: 10px; margin: 5px">
#
# <b> We see that Action has <del> 3369 </del> <span style="background-color:#e6f2ff"> 766 games with the average sales of <del>0.52M</del> <span style="background-color:#e6f2ff"> 0.42M</span> per Action game in sales. Shooter has an average sale of <del> 0.80M </del> <span style="background-color:#e6f2ff"> 1.25M per </span> genre with 187 games. The highest average (we're disregaring the unk genre) is <del>Platform</del> <span style="background-color:#e6f2ff"> Shooter <del>with an average sales per <del> platform game </del> <span style="background-color:#e6f2ff"> Action game of 0.93M by only making 888 games</del>. Adventure had the lowest average of sales with <del>1303</del> <span style="background-color:#e6f2ff"> 245 games for <del>0.18M</del><span style="background-color:#e6f2ff"> 0.10M per Adventure game</b>

# %% [markdown]
# <div style="border: 5px solid green; padding: 10px; margin: 5px">
# <b> Reviewer's comment </b>
#
# Very smart. Action could make such volumes only due to the large number of games, so it's better to evaluate median or mean as well.
# </div>

# %%
# display the growth or decline of sales of each genre per year

# Group by genre and year, sum all regional and total sales
genre_year_growth = df_relevant.groupby(['genre', 'year_of_release'])[
    ['na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'total_sales']
].sum()

# Reset index to make plotting easier
genre_year_growth = genre_year_growth.reset_index()

# Pivot the table to get years on x-axis and genres as columns
pivot_table = genre_year_growth.pivot(index='year_of_release', columns='genre', values='total_sales')

x_data = genre_year_growth['year_of_release']

y_data = genre_year_growth['total_sales']

# Plot line graph
for genre in pivot_table.columns:
    plt.plot(pivot_table.index, pivot_table[genre], label=genre)

plt.title('Genre Sales Trends Over the Years')
plt.xlim([2013,2016])

# Make the x-axis to show only integer years
plt.xticks([2013,2014,2015,2016])

plt.xlabel('Year of Release')
plt.ylabel('Total Sales (in millions)')
plt.legend(title='Genre')
plt.show()

# %%
display(genre_year_growth)
# Out:
#            genre  year_of_release  na_sales  eu_sales  jp_sales  other_sales  \
# 0         Action             2013     53.52     43.45     10.91        14.63
# 1         Action             2014     38.85     39.86      6.53        11.99
# 2         Action             2015     24.39     24.14     15.98         7.51
# 3         Action             2016      9.29     10.68      7.07         3.07
# 4      Adventure             2013      1.50      1.76      2.22         0.61
# 5      Adventure             2014      1.80      1.82      1.38         0.57
# 6      Adventure             2015      2.89      3.35      1.04         0.88
# 7      Adventure             2016      0.95      1.32      1.18         0.37
# 8       Fighting             2013      3.12      1.86      1.28         0.83
# 9       Fighting             2014      6.89      2.97      4.83         1.16
# 10      Fighting             2015      3.70      2.38      0.79         1.03
# ...

# %% [markdown]
# ### Key Questions for Genre Analysis:
# - Which genres consistently perform well?
#     - Actions games are the highest sales with 3369 action games released with an average sale of 0.52M per Action game. Other genres that are top sale is Sports and Shooter games.
# - Are there any genres showing recent growth or decline?
#     - Since we know that year 2016 is incomplete, the graph above may look like sales are declining so let's only include up to 2015.
#         - Genre's that are inclining (but stable growth): role-playing, adventure, and strategy
#         - There are quite a few genres where they showed a declind after their peak from 2008-2012:
#             - Action, Shooter, Sports, and Platform
# - How does the average performance vary across genres?
#     - Platform has the highest sales average with $0.93M per Platform game while only making 888 games while being ranked 5th in total sales.

# %% [markdown]
# <div style="border: 5px solid blue; padding: 10px; margin: 5px">
# <span style="background-color:#e6f2ff"> <b> I know the comment says good but since I have different results when correcting the code to relevant years, I think it's better just to create a new markdown cell box versus doing the scratch and highlighting it. </b>
#
# <ul>
#     <li><span style="background-color:#e6f2ff">Which genres consistently perform well?</li>
#     <ul>
#         <li><span style="background-color:#e6f2ff"> While Action games are the best seller in 2013 and overall from the 2013-2016; it dropped rapidly throughout the years. Looks like in 2016, Shooter games are the highest sales
#         </li>
#     </ul>
#     <li><span style="background-color:#e6f2ff">Are there any genres showing recent growth or decline? </li>
#     <ul>
#         <li><span style="background-color:#e6f2ff">The genres that has a steady growth are: role-playing, adventure, and strategy</li>
#         <li><span style="background-color:#e6f2ff"> The genres that shows a decline after their peak from 2008-2012: Actoin, Shooter, Sports, and Platform </li>
#     </ul>
#     <li> <span style="background-color:#e6f2ff">How does the average performance vary across genres </li>
#     <ul>
#         <li><span style="background-color:#e6f2ff"> Shooter games has the highest average with 1.25M per game while only making 187 games and ranked 2nd in sales from 2013-2016 </li>
#     </ul>
# </ul>

# %% [markdown]
# <div style="border: 5px solid green; padding: 10px; margin: 5px">
# <b> Reviewer's comment </b>
#
# Good. </div>

# %% [markdown]
# <div style="border: 5px solid green; padding: 10px; margin: 5px">
# <b> Reviewer's comment 2 </b>
#
# Great!
#
# </div>

# %% [markdown]
# # Step 4: Regional Market Analysis and User Profiles
#
# In this section, we will analyze the gaming market characteristics across three major regions: North America (NA), Europe (EU), and Japan (JP). Our analysis will focus on platform preferences, genre popularity, and the impact of ESRB ratings in each region.
#
# ## 4.1 Regional Platform Analysis
#
# Let's begin by examining platform performance across different regions:

# %% [markdown]
# <div style="border: 5px solid red; padding: 10px; margin: 5px">
# <b> Reviewer's comment </b>
#
#
# Please use relevant data. The distributions may change after you use the correct time interval, so don't forget to update the conclusions :)
# </div>

# %%
# Function to analyze platform performance by region
# Let's start with na_sales region
na_platform = df_relevant.groupby('platform')['na_sales'].sum()

# set the top 5 platforms for na_sales 
top5_na_platform = na_platform.sort_values(ascending=False).head(5)

print(f"the top 5 platforms in NA region are: {top5_na_platform.index.tolist()}")
print()

# eu_sales
eu_platform = df_relevant.groupby('platform')['eu_sales'].sum()

# set the top 5 platforms for eu_sales
top5_eu_platforms = eu_platform.sort_values(ascending=False).head(5)

print(f"the top 5 platforms in EU region are: {top5_eu_platforms.index.tolist()}")
print()

# jp_sales
jp_platform = df_relevant.groupby('platform')['jp_sales'].sum()

# set the top 5 platforms for jp_sales
top5_jp_platform = jp_platform.sort_values(ascending=False).head(5)

print(f"the top 5 platforms in jp_sales are: {top5_jp_platform.index.tolist()}")
print()

# finally, other_sales
other_platform = df_relevant.groupby('platform')['other_sales'].sum()

# set the top 5 platforms for other_sales
top5_other_platform = other_platform.sort_values(ascending=False).head(5)

print(f"the top 5 platforms in other_sales are: {top5_other_platform.index.tolist()}")
# Out:
# the top 5 platforms in NA region are: ['PS4', 'XOne', 'X360', 'PS3', '3DS']
#
# the top 5 platforms in EU region are: ['PS4', 'PS3', 'XOne', 'X360', '3DS']
#
# the top 5 platforms in jp_sales are: ['3DS', 'PS3', 'PSV', 'PS4', 'WiiU']
#
# the top 5 platforms in other_sales are: ['PS4', 'PS3', 'XOne', 'X360', '3DS']

# %% [markdown]
# <div style="border: 5px solid blue; padding: 10px; margin: 5px">
#
# <del> We see that region is different. X360 is popular in NA region but it's not in EU or JP regions. I'm actually shocked to see that Wii is not the top 5 platform in jp region but it will in the other 3 region. PS2 is popular in all of the regions which explains why PS2 has the highest number of sales. PS3 is popular in all regions except for jp region. DS is the top platform for NA region and other regions. 3DS is the only popular platform in jp which is no surprise when looking at our previous analysis.</del>
#
# <span style="background-color:#e6f2ff"> We see that 5 platforms are popular in 3 regions (NA, EU, and Other) while JP has their other platforms as their preference. JP's unique platform that's not top 5 in other regions are: PSV and WiiU.</span>
# <ul>
#     <li><span style="background-color:#e6f2ff">PS4, XOne, X360, PS3, 3DS is popular in all regions.</span></li>
#     <li><span style="background-color:#e6f2ff"> PS4, PS3, and 3DS are popular in all regions </span></li>
# </ul>
# </div>

# %% [markdown]
# <div style="border: 5px solid green; padding: 10px; margin: 5px">
# <b> Reviewer's comment 2 </b>
#
# There are some similarities between Europe the Northern America, while  people in Japan prefer portable platforms and japanese market. We definitely should not recommend them XBox :)
# </div>

# %%
# Analyze each region
platform_stats = df_relevant.groupby('platform')['na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'total_sales'].agg(['sum','mean','std'])

display(platform_stats.sort_values(('na_sales','sum'),ascending=False).head(5))

print()

display(platform_stats.sort_values(('eu_sales','sum'),ascending=False).head(5))

print()

display(platform_stats.sort_values(('jp_sales','sum'),ascending=False).head(5))

print()

display(platform_stats.sort_values(('other_sales','sum'),ascending=False).head(5))
# Out:
#          na_sales                     eu_sales                     jp_sales  \
#               sum      mean       std      sum      mean       std      sum
# platform
# PS4        108.74  0.277398  0.583723   141.09  0.359923  0.810843    15.96
# XOne        93.12  0.377004  0.630618    51.59  0.208866  0.365306     0.34
# X360        81.66  0.439032  1.021400    42.52  0.228602  0.538409     0.51
# PS3         63.50  0.184058  0.521613    67.81  0.196551  0.657879    23.35
# 3DS         38.20  0.126073  0.499331    30.96  0.102178  0.381832    67.81
#
#                              other_sales                     total_sales  \
#               mean       std         sum      mean       std         sum
# platform
# PS4       0.040714  0.069101       48.35  0.123342  0.254825      314.14
# XOne      0.001377  0.005153       14.27  0.057773  0.094221      159.32
# X360      0.002742  0.007953       12.11  0.065108  0.146303      136.80
# ...

# %% [markdown]
# ### Cross-Regional Platform Comparison
#
# Let's create a comparative analysis of platform performance across regions:

# %%
# Create a comparative platform analysis

best_platforms = pd.concat([top5_na_platform,top5_eu_platforms,top5_jp_platform,top5_other_platform], axis='columns')
display(best_platforms)
# Out:
#           na_sales  eu_sales  jp_sales  other_sales
# platform
# PS4         108.74    141.09     15.96        48.35
# XOne         93.12     51.59       NaN        14.27
# X360         81.66     42.52       NaN        12.11
# PS3          63.50     67.81     23.35        26.77
# 3DS          38.20     30.96     67.81         6.28
# PSV            NaN       NaN     18.59          NaN
# WiiU           NaN       NaN     10.88          NaN

# %% [markdown]
# #### Note: The NaNs on the table means it's not the platform is not in their top 5 for tha region.

# %%
# Visualize cross-regional comparison for top platforms
best_platforms.plot(kind='bar', rot = 0)
plt.title("Top platforms per Region")
plt.xlabel('platform')
plt.ylabel('Sales $ (in Millions')
plt.show()

# %% [markdown]
# <div style="border: 5px solid blue; padding: 10px; margin: 5px">
# <del>- We see that PS2 is the best platform in all of regions!
# - We see two platforms that is only popular in Japan (SNES and 3DS). If we were currently in the 1990s, SNES would be popular in ALL regions but consoles have developed over the years and expanded in some regions but not all.
# -  Nintendo 3DS seems to only be popular in Japan and no where else. I guess it's a cultural preference. The cultural difference on why it is popular in Japan only is because of:
#     - Daily commute patterns
#     - Gaming culture and social acceptance
# -  X360 and PS2 are the best platforms in the NA region.
#     -  It's also interesting to see the DS have higher sales.
#         -  As for PS2 being a lot higher in PS3, from what I remembered, PS3 had a bad glitch and that's why their Sales didn't do so great compared to PS2. I'm sure there's other factors such as competition (Xbox 360 and Wii)</del>
#     <ul>
#             <li><span style="background-color:#e6f2ff"> We see that EU region has the highest sales for PS4</li>
#             <li><span style="background-color:#e6f2ff"> JP's best selling platform games in 3DS and they're the only region to have top 5 platforms as PSV and WII while other regions is not considered their top 5 platform. I guess 3DS and WiiU are popular in Japan due to cultural preference. The cultural difference on why it is popular Japan only is because: </span></li>
#             <ul>
#                 <li> <span style="background-color:#e6f2ff"> Daily commute patters</span> </li>
#                 <li> <span style="background-color:#e6f2ff">Gaming culture and social acceptance </span></li>
#             </ul>
#             <li> <span style="background-color:#e6f2ff"> While NA leads in the sales in video games of all time, it's interesting to see how much of a preference that EU_sales rather have PS4 consoles over Xbox. </span></li>

# %% [markdown]
# <div style="border: 5px solid green; padding: 10px; margin: 5px">
# <b> Reviewer's comment 2 </b>
#
# In addition, Japanese also don't like shooters as much as in NA and EU people do.
# </div>

# %% [markdown]
# ## 4.2 Regional Genre Analysis
#
# Now let's examine genre preferences across regions:

# %%
# Function to analyze genre performance by region

# Let's start with genre's in na region
na_genre = df_relevant.groupby('genre')['na_sales'].sum()

# set the top 5 genre's for na_sales 
top5_na_genre = na_genre.sort_values(ascending=False).head(5)

print(f"the top 5 genre's in NA region are: {top5_na_genre.index.tolist()}")
print()

# EU genre's
eu_genre = df_relevant.groupby('genre')['eu_sales'].sum()

# set the top 5 genre's for eu_sales
top5_eu_genre = eu_genre.sort_values(ascending=False).head(5)

print(f"the top 5 genre's in EU region are: {top5_eu_genre.index.tolist()}")
print()

# JP genre's
jp_genre = df_relevant.groupby('genre')['jp_sales'].sum()

# set the top 5 genre's for jp_sales
top5_jp_genre = jp_genre.sort_values(ascending=False).head(5)

print(f"the top 5 genre in jp_sales are: {top5_jp_genre.index.tolist()}")
print()

# finally, other regions
other_genre = df_relevant.groupby('genre')['other_sales'].sum()

# set the top 5 genre for other_sales
top5_other_genre = other_genre.sort_values(ascending=False).head(5)

print(f"the top 5 genre's in other regions are: {top5_other_genre.index.tolist()}")
# Out:
# the top 5 genre's in NA region are: ['Action', 'Shooter', 'Sports', 'Role-Playing', 'Misc']
#
# the top 5 genre's in EU region are: ['Action', 'Shooter', 'Sports', 'Role-Playing', 'Racing']
#
# the top 5 genre in jp_sales are: ['Role-Playing', 'Action', 'Misc', 'Fighting', 'Shooter']
#
# the top 5 genre's in other regions are: ['Action', 'Shooter', 'Sports', 'Role-Playing', 'Misc']

# %% [markdown]
# ### Cross-Regional Genre Comparison
#
# Let's compare genre preferences across regions:

# %%
# Create a comparative genre analysis
best_genre = pd.concat([top5_na_genre,top5_eu_genre,top5_jp_genre,top5_other_genre], axis='columns')
display(best_genre)
# Out:
#               na_sales  eu_sales  jp_sales  other_sales
# genre
# Action          126.05    118.13     40.49        37.20
# Shooter         109.74     87.86      6.61        28.77
# Sports           65.27     60.52       NaN        19.45
# Role-Playing     46.40     36.97     51.04        11.48
# Misc             27.49       NaN      9.20         6.09
# Racing             NaN     20.19       NaN          NaN
# Fighting           NaN       NaN      7.65          NaN

# %% [markdown]
# #### Note: The NaNs are not applicable as the top 5 genre's in that region.
#
# ##### It's interesting that Role-Playing is the best genre in the Japan Region with Action in second. As for the other 3 regions, Action is the number 1 genre with sports being second. As for Europe and other regions, Racing is top 5 but it's not top 5 in the other regions. You would think with Mario Kart, Need for Speed, Racing would be in the top genres in all regions.

# %%
# Visualize cross-regional comparison for top genres
best_genre.plot(kind='bar', rot = 0)
plt.title("Top platforms per Genre")
plt.xlabel('Genre')
plt.ylabel('Sales $ (in Millions')
plt.show()

# %% [markdown]
# ## 4.3 ESRB Rating Impact Analysis
#
# Finally, let's examine how ESRB ratings affect sales in each region:

# %%
# Function to analyze ESRB rating impact
ratings = df_relevant.groupby('rating')['na_sales', 'eu_sales', 'jp_sales', 'other_sales','total_sales'].sum()
display(ratings.sort_values('total_sales',ascending=False))
# Out:
#         na_sales  eu_sales  jp_sales  other_sales  total_sales
# rating
# M         165.21    145.32     14.11        47.04       371.68
# E          79.05     83.36     15.14        22.61       200.16
# T          49.79     41.95     20.59        14.29       126.62
# E10+       54.24     42.69      5.89        12.57       115.39

# %%
# Analyze ESRB impact for each region
ratings.drop(columns='total_sales').plot(kind='bar', rot = 0)
plt.title('Sales per Ratings')
plt.xlabel('Ratings')
plt.ylabel('Sales $ (in millions)')
plt.show()

# %% [markdown]
# <div style="border: 5px solid blue; padding: 10px; margin: 5px">
# <del>
# - All regions favors rated E games
# - Japan has the lower sales for E10+ and M games.
# - NA and JP has no interest in RP games
#   </del>
# <del>In conclusion ESRB ratings does influence sales by different regions. Rated E games are guaranteed to be a big hit depending on the game.</del>
#     <ul>
#         <li> All regions favors rated M games</li>
#         <li> EU favors rated E games over NA region</li>
#     </ul>

# %% [markdown]
# <div style="border: 5px solid green; padding: 10px; margin: 5px">
# <b> Reviewer's comment 2 </b>
#
# Good.
# </div>

# %% [markdown]
# # Step 5 : Hypothesis Tests
#
# —Average user ratings of the Xbox One and PC platforms are the same.
#
# —Average user ratings for the Action and Sports genres are different.
#
# Set the *alpha* threshold value yourself.
#
# Explain:
#
# —How you formulated the null and alternative hypotheses
#
# —What criteria you used to test the hypotheses~~,~~ and why

# %%
# Hypothesis 1: Average user ratings of the Xbox One and PC platforms are the same.
xbox1 = df_relevant[df_relevant['platform'] == 'XOne']['user_score']
xbox1 = pd.to_numeric(xbox1, errors='coerce')
xbox1 = xbox1.dropna()

pc = df_relevant[df_relevant['platform'] == 'PC']['user_score']
pc = pd.to_numeric(pc, errors='coerce')
pc = pc.dropna()

# calculate the p-value
alpha = 0.05
plat_results = st.ttest_ind(xbox1,pc)

print('p-value: ', plat_results.pvalue)

if plat_results.pvalue < alpha:
    print("We reject null hypothesis: Average user ratings for Xbox One and PC are different.")
else:
    print("We can't reject the null hypothesis: Average user ratings for Xbox One and PC are equal.")
# Out:
# p-value:  0.14012658403611647
# We can't reject the null hypothesis: Average user ratings for Xbox One and PC are equal.

# %%
# Hypothesis 2: Average user ratings for the Action and Sports genres are different. 
action = df_relevant[df_relevant['genre'] == 'Action']['user_score']
action = pd.to_numeric(action, errors='coerce')
action = action.dropna()

sports = df_relevant[df_relevant['genre'] == 'Sports']['user_score']
sports = pd.to_numeric(sports, errors='coerce')
sports = sports.dropna()

# set p-value
alpha = 0.05
genre_results = st.ttest_ind(action,sports)

print('p-value: ', genre_results.pvalue)

if genre_results.pvalue < 0.05:
    print('We reject the null hypothesis: Average user ratings for Action and Sports genres are different.')
else:
    print("We can't reject the null hypothesis: Average user ratings for Action and Sports genres are equal.")
# Out:
# p-value:  1.0517832389140023e-27
# We reject the null hypothesis: Average user ratings for Action and Sports genres are different.

# %% [markdown]
# ### Testing Hypothesis 1: Average user ratings for Xbox vs PC platforms
# - Choosed a two-tailed test to test any difference, regardless if one sample size is bigger than the other.
# - testing the null hypothesis to see if the average user ratings for Xbox 1 and PC platforms are the same
#
# ### Testing Hypothesis 2: Average user rating for Action vs Sports Genre
# - Choosed a two-tailed test to test any difference between action vs sports genre regardless of different sample sizes.
# - testing the null hypothesis to see if the average user ratings for Action vs Sports genre

# %% [markdown]
# <div style="border: 5px solid red; padding: 10px; margin: 5px">
# <b> Reviewer's comment </b>
#
# - Please add wordings for both tests.  H0 and H1 for the 1st hypotheses pair and H0 and H1 for the second one.  Be sure to clarify, why you decided to use a specific statistical test and why you chose a specific significance level.
#
#
# - Here we also need relevant time interval. </div>

# %% [markdown]
# # Step 6. Write a general conclusion

# %% [markdown]
# ~~### Data Quality~~
# - ~~Out of the 16715 entries, we had significant missing values in critic_score, user_score, and rating (with only a few missing with genre and year_of_release)~~
# - ~~Most of the missing values were during the 2006-2011, when the volume of game releases peaked~~
# - ~~Decided to leave the missing values as is for user_score and critic_score to avoid skewing averages and compromising hypothesis testing~~
# - ~~As for missing values for 'genre', I fill in the blank as 'unk' and year_of_release as 0 so I can convert to integer and noted year 0 is 'unknown'~~
# - ~~Detected an error for one of the games for Nintendo DS game showing a release year of 1985 when Nintendo DS wasn't released till 2004. Looked up when the game was released and manually corrected it.~~
#
# ~~### Lifecycle and Market Trends~~
# ~~- The peak of video game releases was from ~~2006-2011~~**2013-2016**~~.
# ~~- PS4 launched in 2013 and dominated sales across all regions through 2016~~
#     ~~- Xbox One shows signifciant sales growth, with 185.18% increase in 2014 and 11.23% in 2015.~~
# - ~~PS# still contributes notable sales but is clearly declining and is towards the end of its lifecycle.~~
# - ~~3DS shows strong presence, especially in Japan, despite gradual decline.~~
# - ~~The average lifecycle of a platform is 7 years, with exceptions such as PC, which continues steadily across decades~~.
#
# ~~### Genre~~
# ~~- From 2013-2016:The top genre leaderss are Actoin and Shooter.~~
# ~~- Action had the highest total sales for 766 games at 0.42M per game~~.
# ~~- Role-Playing and Adventure showed steady growth~~.
# ~~- Sports, Platform, and Action genres showed declines from 2013-2016 despite the fact that action is their best seller due to their highest peak in 2013~~.
# ~~- Adventure had the lowest average sales at 0.10M per game~~.
#
# ~~### Regional~~
# ~~- PS4, PS3, and 3DS were popular in all regoins~~.
# ~~- Japan's market showed a preference of 3DS, WiiU, and PSV due to handheld platforms~~
# ~~- Europe sales for PS4 outpaced NA in many cases. Their strong preferenc is rated E games.~~
# ~~- Rated M games is the strong preference in all regions but less so in Japan.~~
# ~~- NA still leads in overall sales, but JP showed strength with 3DS and Role-Playing Games~~
#
# ~~### Correlations between users and sales~~
# ~~- There were a moderate correlation between critic_score and user_score, but neither strongly correlated with sales.~~
# ~~- Sales appeared right-skewed, driven by a few blockbuster titles~~
# ~~- Possible explanations: low number of review for some games, outlier influence from blockbuster hits, data error since there were missing data from released games in the 1980s. Some of the data for reviews must've been dropped for a lot of data conversion for the past 30+ years.~~
#
# ~~### Hypothesis Testing~~
# ~~- #### Hypothesis 1:~~
#    ~~- H0(null): Average user ratings for Xbox One and PC platforms are equal~~
#     ~~- H1(alt): Average user ratings for Xbox One and PC platforms are different~~
#     ~~- p-value is 0.1401 so the result was Fail to reject H0 - No statistically significant difference found~~
#     ~~- We used a two-tailed independent t-test due to comparing two independent groups with unknown variance.~~
#
# ~~- #### Hypothesis 2:~~
#     ~~-  H0(null): Average user ratings for Action and Sports genres are equal~~
#     ~~-  H1(alt): Average user ratings for Action and Sports genres are different~~
#     ~~-  p-value: pratically 0 so the result was to reject H0 - Statistically signifcant difference found.~~
#     ~~-  We used two-tailed independent t-test due to comparing averages between two genres with different sample sizes.~~
#
# ~~### Recommendations~~
# ~~- Focus 2017 marketing on PS4, Xbox One, and 3DS, which have the most recent activity and solid average sales.~~
# ~~- Target Action and Role-Playing genres, especially in Japan and Europe, while focusing on the decline in Sports genre.~~
# ~~- Make E-rated games the highest priority since it performed best across all markets, especially in family-friendly environment and users with handheld platforms.~~
# ~~- Focus more on historical sales performance rather than review scores when predicting marketing success since the scores doesn't show a strong coorelation with the actual sales.~~

# %% [markdown]
# <div style="border: 5px solid blue; padding: 10px; margin: 5px">
#
# <h3>Data Quality</h3>
# <ul>
#   <li>Out of the 16,715 entries, we had significant missing values in critic_score, user_score, and rating (only a few missing in genre and year_of_release).</li>
#   <li>Most missing values occurred between 2006–2011, when game releases peaked.</li>
#   <li>Left user_score and critic_score as is to avoid skewing averages and compromising hypothesis testing.</li>
#   <li>Filled missing genre as 'unk' and year_of_release as 0 ("unknown") for integer conversion.</li>
#   <li>Corrected an error for a Nintendo DS game with an invalid 1985 release year (actual year: 2007).</li>
# </ul>
#
# <h3>Lifecycle and Market Trends</h3>
# <ul>
#   <li>The peak of video game releases was <b>2013–2016</b>.</li>
#   <li>PS4 launched in 2013 and dominated sales across all regions through 2016.</li>
#   <li>Xbox One had significant growth: +185.18% in 2014, +11.23% in 2015.</li>
#   <li>PS3 was still active but clearly in decline.</li>
#   <li>3DS showed strong presence in Japan despite gradual decline.</li>
#   <li>Average console lifecycle: ~7 years (with PC as a long-running exception).</li>
# </ul>
#
# <h3>Genre</h3>
# <ul>
#   <li>From 2013–2016, the top genres were Action and Shooter.</li>
#   <li>Action had the highest total sales: 766 games averaging 0.42M each.</li>
#   <li>Role-Playing and Adventure genres showed steady growth.</li>
#   <li>Sports, Platform, and Action genres declined post-2013.</li>
#   <li>Adventure had the lowest average sales: 0.10M per game.</li>
# </ul>
#
# <h3>Regional</h3>
# <ul>
#   <li>PS4, PS3, and 3DS were popular across all regions.</li>
#   <li>Japan favored handhelds: 3DS, WiiU, and PSV.</li>
#   <li>Europe often outpaced NA in PS4 sales; preferred E-rated games.</li>
#   <li>M-rated games dominated globally but were less favored in Japan.</li>
#   <li>NA led in overall sales; JP showed strength in 3DS and Role-Playing genres.</li>
# </ul>
#
# <h3>Correlations Between Users and Sales</h3>
# <ul>
#   <li>Moderate correlation between critic_score and user_score, but neither strongly correlated with sales.</li>
#   <li>Sales were right-skewed due to a few blockbuster titles.</li>
#   <li>Potential explanations: low review counts, influence from outliers, or missing historic review data.</li>
# </ul>
#
# <h3>Hypothesis Testing</h3>
#
# <b>Hypothesis 1:</b>
# <ul>
#   <li><b>H₀:</b> Average user ratings for Xbox One and PC are equal.</li>
#   <li><b>H₁:</b> Average user ratings for Xbox One and PC are different.</li>
#   <li><b>p-value:</b> 0.1401 → Fail to reject H₀.</li>
#   <li>Conclusion: No statistically significant difference found.</li>
#   <li>Test used: Two-tailed independent t-test.</li>
# </ul>
#
# <b>Hypothesis 2:</b>
# <ul>
#   <li><b>H₀:</b> Average user ratings for Action and Sports genres are equal.</li>
#   <li><b>H₁:</b> Average user ratings for Action and Sports genres are different.</li>
#   <li><b>p-value:</b> ~0 → Reject H₀.</li>
#   <li>Conclusion: Statistically significant difference found.</li>
#   <li>Test used: Two-tailed independent t-test.</li>
# </ul>
#
# <h3>Recommendations</h3>
# <ul>
#   <li>Focus 2017 marketing on PS4, Xbox One, and 3DS.</li>
#   <li>Prioritize Action and Role-Playing genres, especially in Japan and Europe.</li>
#   <li>De-emphasize Sports due to decline.</li>
#   <li>Invest in E-rated games for family-friendly and handheld platforms.</li>
#   <li>Rely more on historical sales data than review scores, due to weak correlation with sales.</li>
# </ul>
#
# </div>

# %% [markdown]
# <div style="border: 5px solid green; padding: 10px; margin: 5px">
# <b> Reviewer's comment 2 </b>
#
# Good. The null hypothesis always includes the equality sign, it states the absense of any effect. This is because the test does not understand exactly how we set the problem: we can say, for instance, let's make sure that they are not equal. Or that they are equal. And regardless of the purpose of our study, we always put equality at null hypothesis. Then the test result is interpreted correctly.
#
# </div>

# %% [markdown]
# <div style="border: 5px solid green; padding: 10px; margin: 5px">
# <b> Reviewer's comment </b>
#
#
#
# The conclusion is written well.
# </div>
#
# <div style="border: 5px solid red; padding: 10px; margin: 5px">
# <b> Reviewer's comment </b>
#
# Don't forget to update the final conclusion if needed.
# </div>
